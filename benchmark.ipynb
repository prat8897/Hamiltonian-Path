# %%
import numpy as np
import itertools
from itertools import combinations
from multiprocessing import get_context
from typing import Optional, Tuple, List
from path_helpers import process_edge  # Ensure this is correctly implemented

def solve_hamiltonian_path_dp(distance_matrix: np.ndarray) -> Tuple[Optional[List[int]], float]:
    """
    Solve the Hamiltonian Path problem using dynamic programming.
    Time complexity: O(n^2 * 2^n)
    Space complexity: O(n * 2^n)
    
    Args:
        distance_matrix: n x n matrix of distances between points
        
    Returns:
        tuple: (optimal path, optimal distance) or (None, float('inf')) if no path exists
    """
    n = len(distance_matrix)
    # dp[mask][end] represents the minimum distance to visit all vertices in mask
    # and end at vertex 'end'
    dp = {}
    # prev[mask][end] stores the previous vertex in the optimal path
    prev = {}
    
    # Initialize dp array for single vertices
    for i in range(n):
        mask = 1 << i  # Create a mask with only vertex i
        dp[(mask, i)] = 0
    
    # Iterate through all possible subsets of vertices
    for size in range(2, n + 1):
        for subset in combinations(range(n), size):
            # Convert subset to bit mask
            mask = sum(1 << i for i in subset)
            
            # Try each vertex as the end point
            for end in subset:
                # Remove end point from consideration
                prev_mask = mask ^ (1 << end)
                min_dist = float('inf')
                best_prev = None
                
                # Try each vertex as the previous point
                for prev_end in subset:
                    if prev_end != end:
                        # Check if we can improve current solution
                        curr_dist = dp.get((prev_mask, prev_end), float('inf'))
                        if curr_dist != float('inf'):
                            total_dist = curr_dist + distance_matrix[prev_end][end]
                            if total_dist < min_dist:
                                min_dist = total_dist
                                best_prev = prev_end
                
                if min_dist != float('inf'):
                    dp[(mask, end)] = min_dist
                    prev[(mask, end)] = best_prev
    
    # Find the optimal solution
    final_mask = (1 << n) - 1  # All vertices visited
    min_total_dist = float('inf')
    best_end = None
    
    for end in range(n):
        if (final_mask, end) in dp and dp[(final_mask, end)] < min_total_dist:
            min_total_dist = dp[(final_mask, end)]
            best_end = end
    
    if best_end is None:
        return None, float('inf')
    
    # Reconstruct the path
    path = []
    current_end = best_end
    current_mask = final_mask
    
    while current_mask:
        path.append(current_end)
        next_mask = current_mask ^ (1 << current_end)
        current_end = prev.get((current_mask, current_end))
        current_mask = next_mask
        
        if current_end is None:
            break
    
    return list(reversed(path)), min_total_dist

def benchmark_hamiltonian_path(n: int = 12, instances: int = 10, seed: int = 42) -> None:
    """
    Benchmark the custom parallel Hamiltonian Path algorithm against the DP solution.
    
    Args:
        n: Number of points in each instance.
        instances: Number of instances to benchmark.
        seed: Base seed for random number generation.
        
    Returns:
        None
    """
    custom_distances: List[float] = []
    dp_distances: List[float] = []
    
    print(f"Starting Benchmark: {instances} instances with n={n} points each.\n")
    
    for instance in range(1, instances + 1):
        current_seed = seed + instance  # Different seed for each instance
        np.random.seed(current_seed)
        points = np.random.rand(n, 2)
        
        # Compute distance matrix
        distance_matrix = np.zeros((n, n))
        for i in range(n):
            for j in range(n):
                if i != j:
                    distance_matrix[i][j] = np.linalg.norm(points[i] - points[j])
        
        edges = list(itertools.combinations(range(n), 2))
        print(f"Instance {instance}: Processing {len(edges)} edges...")
        
        # Prepare arguments for multiprocessing
        args_list = [(edge, n, distance_matrix) for edge in edges]
        
        # Use multiprocessing with 'spawn' start method
        ctx = get_context('spawn')
        with ctx.Pool() as pool:
            results = pool.map(process_edge, args_list)
        
        # Filter out None results and find the best path
        complete_paths = [result for result in results if result is not None]
        
        if not complete_paths:
            print(f"Instance {instance}: No complete path found by the custom algorithm.\n")
            break  # Exit benchmarking as per instructions
        
        # Find the best path from custom algorithm
        best_result = min(complete_paths, key=lambda x: x[0])
        best_distance, best_path, _ = best_result
        custom_distances.append(best_distance)
        
        # Solve using Dynamic Programming
        dp_path, dp_distance = solve_hamiltonian_path_dp(distance_matrix)
        if dp_path is None:
            print(f"Instance {instance}: No complete path found by DP.\n")
            break  # Exit benchmarking as per instructions
        dp_distances.append(dp_distance)
        
        # Compare distances using np.isclose to account for floating-point precision
        # Define a tolerance level (you can adjust 'atol' and 'rtol' as needed)
        are_close = np.isclose(best_distance, dp_distance, atol=1e-8, rtol=1e-5)
        
        if not are_close and best_distance > dp_distance:
            print(f"Instance {instance}: Custom distance {best_distance:.8f} > DP distance {dp_distance:.8f} with current seed {current_seed}")
            print("Benchmark terminated: Custom algorithm found a worse solution than DP.")
            break  # Exit benchmarking as per instructions
        else:
            if are_close:
                comparison = "≈"  # Approximately equal
            else:
                comparison = "<="
            print(f"Instance {instance}: Custom distance {best_distance:.8f} {comparison} DP distance {dp_distance:.8f}.\n")
    
    # Summary of Benchmarking
    total_run = len(custom_distances)
    if total_run == 0:
        print("No instances were successfully benchmarked.")
        return
    
    print("Benchmarking Summary:")
    print(f"Total Instances Run: {total_run} out of {instances}")
    print(f"Custom Algorithm - Average Distance: {np.mean(custom_distances):.8f}")
    print(f"DP Solution       - Average Distance: {np.mean(dp_distances):.8f}")
    improvement_percent = ((np.mean(dp_distances) - np.mean(custom_distances)) / np.mean(dp_distances)) * 100
    print(f"Average Improvement by Custom Algorithm: {improvement_percent:.2f}%")

# %%
benchmark_hamiltonian_path(n=12, instances=1000, seed=142)
# Out:
# Starting Benchmark: 1000 instances with n=12 points each.
#
# Instance 1: Processing 66 edges...
# Instance 1: Custom distance 2.4854 <= DP distance 2.4854.
#
# Instance 2: Processing 66 edges...
# Instance 2: Custom distance 2.5647 <= DP distance 2.5647.
#
# Instance 3: Processing 66 edges...
# Instance 3: Custom distance 2.7318 <= DP distance 2.7318.
#
# Instance 4: Processing 66 edges...
# Instance 4: Custom distance 2.5117 <= DP distance 2.5117.
#
# Instance 5: Processing 66 edges...
# Instance 5: Custom distance 2.4828 <= DP distance 2.4828.
#
# Instance 6: Processing 66 edges...
# Instance 6: Custom distance 2.9024 <= DP distance 2.9024.
#
# Instance 7: Processing 66 edges...
# Instance 7: Custom distance 2.4139 <= DP distance 2.4139.
#
# Instance 8: Processing 66 edges...
# Instance 8: Custom distance 2.5610 <= DP distance 2.5610.
#
# Instance 9: Processing 66 edges...
# Instance 9: Custom distance 2.3531 <= DP distance 2.3531.
#
# Instance 10: Processing 66 edges...
# Instance 10: Custom distance 2.4467 <= DP distance 2.4467.
#
# Instance 11: Processing 66 edges...
# Instance 11: Custom distance 2.4496 <= DP distance 2.4496.
#
# Instance 12: Processing 66 edges...
# Instance 12: Custom distance 2.2786 <= DP distance 2.2786.
#
# Instance 13: Processing 66 edges...
# Instance 13: Custom distance 2.0450 <= DP distance 2.0450.
#
# Instance 14: Processing 66 edges...
# Instance 14: Custom distance 2.3166 <= DP distance 2.3166.
#
# Instance 15: Processing 66 edges...
# Instance 15: Custom distance 2.2603 <= DP distance 2.2603.
#
# Instance 16: Processing 66 edges...
# Instance 16: Custom distance 2.6636 <= DP distance 2.6636.
#
# Instance 17: Processing 66 edges...
# Instance 17: Custom distance 2.8175 <= DP distance 2.8175.
#
# Instance 18: Processing 66 edges...
# Instance 18: Custom distance 2.9215 <= DP distance 2.9215.
#
# Instance 19: Processing 66 edges...
# Instance 19: Custom distance 2.1931 <= DP distance 2.1931.
#
# Instance 20: Processing 66 edges...
# Instance 20: Custom distance 2.4374 <= DP distance 2.4374.
#
# Instance 21: Processing 66 edges...
# Instance 21: Custom distance 2.0309 <= DP distance 2.0309.
#
# Instance 22: Processing 66 edges...
# Instance 22: Custom distance 2.4773 <= DP distance 2.4773.
#
# Instance 23: Processing 66 edges...
# Instance 23: Custom distance 2.5080 <= DP distance 2.5080.
#
# Instance 24: Processing 66 edges...
# Instance 24: Custom distance 2.2026 <= DP distance 2.2026.
#
# Instance 25: Processing 66 edges...
# Instance 25: Custom distance 2.3348 <= DP distance 2.3348.
#
# Instance 26: Processing 66 edges...
# Instance 26: Custom distance 2.0424 <= DP distance 2.0424.
#
# Instance 27: Processing 66 edges...
# Instance 27: Custom distance 2.6467 <= DP distance 2.6467.
#
# Instance 28: Processing 66 edges...
# Instance 28: Custom distance 2.7859 <= DP distance 2.7859.
#
# Instance 29: Processing 66 edges...
# Instance 29: Custom distance 2.2665 <= DP distance 2.2665.
#
# Instance 30: Processing 66 edges...
# Instance 30: Custom distance 1.9171 <= DP distance 1.9171.
#
# Instance 31: Processing 66 edges...
# Instance 31: Custom distance 2.5321 <= DP distance 2.5321.
#
# Instance 32: Processing 66 edges...
# Instance 32: Custom distance 2.1776 <= DP distance 2.1776.
#
# Instance 33: Processing 66 edges...
# Instance 33: Custom distance 2.5873 <= DP distance 2.5873.
#
# Instance 34: Processing 66 edges...
# Instance 34: Custom distance 2.4509 <= DP distance 2.4509.
#
# Instance 35: Processing 66 edges...
# Instance 35: Custom distance 2.1677 <= DP distance 2.1677.
#
# Instance 36: Processing 66 edges...
# Instance 36: Custom distance 2.5556 <= DP distance 2.5556.
#
# Instance 37: Processing 66 edges...
# Instance 37: Custom distance 2.4045 <= DP distance 2.4045.
#
# Instance 38: Processing 66 edges...
# Instance 38: Custom distance 2.2882 <= DP distance 2.2882.
#
# Instance 39: Processing 66 edges...
# Instance 39: Custom distance 2.5175 <= DP distance 2.5175.
#
# Instance 40: Processing 66 edges...
# Instance 40: Custom distance 2.4087 <= DP distance 2.4087.
#
# Instance 41: Processing 66 edges...
# Instance 41: Custom distance 2.1467 <= DP distance 2.1467.
#
# Instance 42: Processing 66 edges...
# Instance 42: Custom distance 2.6921 <= DP distance 2.6921.
#
# Instance 43: Processing 66 edges...
# Instance 43: Custom distance 2.6054 <= DP distance 2.6054.
#
# Instance 44: Processing 66 edges...
# Instance 44: Custom distance 2.5700 <= DP distance 2.5700.
#
# Instance 45: Processing 66 edges...
# Instance 45: Custom distance 2.3988 <= DP distance 2.3988.
#
# Instance 46: Processing 66 edges...
# Instance 46: Custom distance 2.6739 <= DP distance 2.6739.
#
# Instance 47: Processing 66 edges...
# Instance 47: Custom distance 2.2098 <= DP distance 2.2098.
#
# Instance 48: Processing 66 edges...
# Instance 48: Custom distance 2.3994 <= DP distance 2.3994.
#
# Instance 49: Processing 66 edges...
# Instance 49: Custom distance 2.6588 <= DP distance 2.6588.
#
# Instance 50: Processing 66 edges...
# Instance 50: Custom distance 2.1564 <= DP distance 2.1564.
#
# Instance 51: Processing 66 edges...
# Instance 51: Custom distance 2.4091 <= DP distance 2.4091.
#
# Instance 52: Processing 66 edges...
# Instance 52: Custom distance 2.9928 <= DP distance 2.9928.
#
# Instance 53: Processing 66 edges...
# Instance 53: Custom distance 2.3964 <= DP distance 2.3964.
#
# Instance 54: Processing 66 edges...
# Instance 54: Custom distance 2.6719 <= DP distance 2.6719.
#
# Instance 55: Processing 66 edges...
# Instance 55: Custom distance 2.0472 <= DP distance 2.0472.
#
# Instance 56: Processing 66 edges...
# Instance 56: Custom distance 2.3083 <= DP distance 2.3083.
#
# Instance 57: Processing 66 edges...
# Instance 57: Custom distance 2.7036 <= DP distance 2.7036.
#
# Instance 58: Processing 66 edges...
# Instance 58: Custom distance 2.3096 <= DP distance 2.3096.
#
# Instance 59: Processing 66 edges...
# Instance 59: Custom distance 2.3368 <= DP distance 2.3368.
#
# Instance 60: Processing 66 edges...
# Instance 60: Custom distance 2.4533 <= DP distance 2.4533.
#
# Instance 61: Processing 66 edges...
# Instance 61: Custom distance 2.4183 <= DP distance 2.4183.
#
# Instance 62: Processing 66 edges...
# Instance 62: Custom distance 2.1509 <= DP distance 2.1509.
#
# Instance 63: Processing 66 edges...
# Instance 63: Custom distance 2.4173 <= DP distance 2.4173.
#
# Instance 64: Processing 66 edges...
# Instance 64: Custom distance 2.2627 <= DP distance 2.2627.
#
# Instance 65: Processing 66 edges...
# Instance 65: Custom distance 2.3110 <= DP distance 2.3110.
#
# Instance 66: Processing 66 edges...
# Instance 66: Custom distance 2.8020 <= DP distance 2.8020.
#
# Instance 67: Processing 66 edges...
# Instance 67: Custom distance 2.4629 <= DP distance 2.4629.
#
# Instance 68: Processing 66 edges...
# Instance 68: Custom distance 2.7561 <= DP distance 2.7561.
#
# Instance 69: Processing 66 edges...
# Instance 69: Custom distance 2.5029 <= DP distance 2.5029.
#
# Instance 70: Processing 66 edges...
# Instance 70: Custom distance 2.5455 <= DP distance 2.5455.
#
# Instance 71: Processing 66 edges...
# Instance 71: Custom distance 2.3551 <= DP distance 2.3551.
#
# Instance 72: Processing 66 edges...
# Instance 72: Custom distance 2.6350 <= DP distance 2.6350.
#
# Instance 73: Processing 66 edges...
# Instance 73: Custom distance 2.1041 <= DP distance 2.1041.
#
# Instance 74: Processing 66 edges...
# Instance 74: Custom distance 2.0788 <= DP distance 2.0788.
#
# Instance 75: Processing 66 edges...
# Instance 75: Custom distance 2.2136 <= DP distance 2.2136.
#
# Instance 76: Processing 66 edges...
# Instance 76: Custom distance 2.1865 <= DP distance 2.1865.
#
# Instance 77: Processing 66 edges...
# Instance 77: Custom distance 2.5483 <= DP distance 2.5483.
#
# Instance 78: Processing 66 edges...
# Instance 78: Custom distance 2.4604 <= DP distance 2.4604.
#
# Instance 79: Processing 66 edges...
# Instance 79: Custom distance 2.6848 <= DP distance 2.6848.
#
# Instance 80: Processing 66 edges...
# Instance 80: Custom distance 2.7998 <= DP distance 2.7998.
#
# Instance 81: Processing 66 edges...
# Instance 81: Custom distance 2.5664 <= DP distance 2.5664.
#
# Instance 82: Processing 66 edges...
# Instance 82: Custom distance 2.0495 <= DP distance 2.0495.
#
# Instance 83: Processing 66 edges...
# Instance 83: Custom distance 2.4508 <= DP distance 2.4508.
#
# Instance 84: Processing 66 edges...
# Instance 84: Custom distance 2.3433 <= DP distance 2.3433.
#
# Instance 85: Processing 66 edges...
# Instance 85: Custom distance 2.4807 <= DP distance 2.4807.
#
# Instance 86: Processing 66 edges...
# Instance 86: Custom distance 2.3894 <= DP distance 2.3894.
#
# Instance 87: Processing 66 edges...
# Instance 87: Custom distance 2.0051 <= DP distance 2.0051.
#
# Instance 88: Processing 66 edges...
# Instance 88: Custom distance 2.3358 <= DP distance 2.3358.
#
# Instance 89: Processing 66 edges...
# Instance 89: Custom distance 2.7315 <= DP distance 2.7315.
#
# Instance 90: Processing 66 edges...
# Instance 90: Custom distance 2.2438 <= DP distance 2.2438.
#
# Instance 91: Processing 66 edges...
# Instance 91: Custom distance 2.3847 <= DP distance 2.3847.
#
# Instance 92: Processing 66 edges...
# Instance 92: Custom distance 2.8111 <= DP distance 2.8111.
#
# Instance 93: Processing 66 edges...
# Instance 93: Custom distance 2.6891 <= DP distance 2.6891.
#
# Instance 94: Processing 66 edges...
# Instance 94: Custom distance 2.3928 <= DP distance 2.3928.
#
# Instance 95: Processing 66 edges...
# Instance 95: Custom distance 2.2077 <= DP distance 2.2077.
#
# Instance 96: Processing 66 edges...
# Instance 96: Custom distance 2.8708 <= DP distance 2.8708.
#
# Instance 97: Processing 66 edges...
# Instance 97: Custom distance 2.6736 <= DP distance 2.6736.
#
# Instance 98: Processing 66 edges...
# Instance 98: Custom distance 2.5789 <= DP distance 2.5789.
#
# Instance 99: Processing 66 edges...
# Instance 99: Custom distance 2.5372 <= DP distance 2.5372.
#
# Instance 100: Processing 66 edges...
# Instance 100: Custom distance 2.1669 <= DP distance 2.1669.
#
# Instance 101: Processing 66 edges...
# Instance 101: Custom distance 2.1108 <= DP distance 2.1108.
#
# Instance 102: Processing 66 edges...
# Instance 102: Custom distance 2.6062 <= DP distance 2.6062.
#
# Instance 103: Processing 66 edges...
# Instance 103: Custom distance 2.8992 <= DP distance 2.8992.
#
# Instance 104: Processing 66 edges...
# Instance 104: Custom distance 2.0954 <= DP distance 2.0954.
#
# Instance 105: Processing 66 edges...
# Instance 105: Custom distance 2.4736 <= DP distance 2.4736.
#
# Instance 106: Processing 66 edges...
# Instance 106: Custom distance 2.5066 <= DP distance 2.5066.
#
# Instance 107: Processing 66 edges...
# Instance 107: Custom distance 2.4539 <= DP distance 2.4539.
#
# Instance 108: Processing 66 edges...
# Instance 108: Custom distance 2.5787 <= DP distance 2.5787.
#
# Instance 109: Processing 66 edges...
# Instance 109: Custom distance 3.0631 <= DP distance 3.0631.
#
# Instance 110: Processing 66 edges...
# Instance 110: Custom distance 3.0123 <= DP distance 3.0123.
#
# Instance 111: Processing 66 edges...
# Instance 111: Custom distance 2.2481 <= DP distance 2.2481.
#
# Instance 112: Processing 66 edges...
# Instance 112: Custom distance 2.3107 <= DP distance 2.3107.
#
# Instance 113: Processing 66 edges...
# Instance 113: Custom distance 2.2800 <= DP distance 2.2800.
#
# Instance 114: Processing 66 edges...
# Instance 114: Custom distance 2.7545 <= DP distance 2.7545.
#
# Instance 115: Processing 66 edges...
# Instance 115: Custom distance 2.6517 <= DP distance 2.6517.
#
# Instance 116: Processing 66 edges...
# Instance 116: Custom distance 2.5533 <= DP distance 2.5533.
#
# Instance 117: Processing 66 edges...
# Instance 117: Custom distance 2.2938 <= DP distance 2.2938.
#
# Instance 118: Processing 66 edges...
# Instance 118: Custom distance 2.5667 <= DP distance 2.5667.
#
# Instance 119: Processing 66 edges...
# Instance 119: Custom distance 2.3649 <= DP distance 2.3649.
#
# Instance 120: Processing 66 edges...
# Instance 120: Custom distance 2.6958 <= DP distance 2.6958.
#
# Instance 121: Processing 66 edges...
# Instance 121: Custom distance 2.4417 <= DP distance 2.4417.
#
# Instance 122: Processing 66 edges...
# Instance 122: Custom distance 2.5972 <= DP distance 2.5972.
#
# Instance 123: Processing 66 edges...
# Instance 123: Custom distance 2.6484 <= DP distance 2.6484.
#
# Instance 124: Processing 66 edges...
# Instance 124: Custom distance 2.8238 <= DP distance 2.8238.
#
# Instance 125: Processing 66 edges...
# Instance 125: Custom distance 2.5885 <= DP distance 2.5885.
#
# Instance 126: Processing 66 edges...
# Instance 126: Custom distance 2.5767 <= DP distance 2.5767.
#
# Instance 127: Processing 66 edges...
# Instance 127: Custom distance 2.4273 <= DP distance 2.4273.
#
# Instance 128: Processing 66 edges...
# Instance 128: Custom distance 2.7646 <= DP distance 2.7646.
#
# Instance 129: Processing 66 edges...
# Instance 129: Custom distance 2.1882 <= DP distance 2.1882.
#
# Instance 130: Processing 66 edges...
# Instance 130: Custom distance 2.2750 <= DP distance 2.2750.
#
# Instance 131: Processing 66 edges...
# Instance 131: Custom distance 2.8452 <= DP distance 2.8452.
#
# Instance 132: Processing 66 edges...
# Instance 132: Custom distance 2.7167 <= DP distance 2.7167.
#
# Instance 133: Processing 66 edges...
# Instance 133: Custom distance 2.3765 <= DP distance 2.3765.
#
# Instance 134: Processing 66 edges...
# Instance 134: Custom distance 3.1898 <= DP distance 3.1898.
#
# Instance 135: Processing 66 edges...
# Instance 135: Custom distance 2.0745 <= DP distance 2.0745.
#
# Instance 136: Processing 66 edges...
# Instance 136: Custom distance 2.2302 <= DP distance 2.2302.
#
# Instance 137: Processing 66 edges...
# Instance 137: Custom distance 2.8292 <= DP distance 2.8292.
#
# Instance 138: Processing 66 edges...
# Instance 138: Custom distance 2.2745 <= DP distance 2.2745.
#
# Instance 139: Processing 66 edges...
# Instance 139: Custom distance 2.4002 <= DP distance 2.4002.
#
# Instance 140: Processing 66 edges...
# Instance 140: Custom distance 2.5252 <= DP distance 2.5252.
#
# Instance 141: Processing 66 edges...
# Instance 141: Custom distance 2.8189 <= DP distance 2.8189.
#
# Instance 142: Processing 66 edges...
# Instance 142: Custom distance 2.3672 <= DP distance 2.3672.
#
# Instance 143: Processing 66 edges...
# Instance 143: Custom distance 1.8904 <= DP distance 1.8904.
#
# Instance 144: Processing 66 edges...
# Instance 144: Custom distance 2.5905 <= DP distance 2.5905.
#
# Instance 145: Processing 66 edges...
# Instance 145: Custom distance 2.6369 <= DP distance 2.6369.
#
# Instance 146: Processing 66 edges...
# Instance 146: Custom distance 2.4043 <= DP distance 2.4043.
#
# Instance 147: Processing 66 edges...
# Instance 147: Custom distance 2.5770 <= DP distance 2.5770.
#
# Instance 148: Processing 66 edges...
# Instance 148: Custom distance 3.0030 <= DP distance 3.0030.
#
# Instance 149: Processing 66 edges...
# Instance 149: Custom distance 2.4266 <= DP distance 2.4266.
#
# Instance 150: Processing 66 edges...
# Instance 150: Custom distance 2.8556 <= DP distance 2.8556.
#
# Instance 151: Processing 66 edges...
# Instance 151: Custom distance 2.6272 <= DP distance 2.6272.
#
# Instance 152: Processing 66 edges...
# Instance 152: Custom distance 2.4728 <= DP distance 2.4728.
#
# Instance 153: Processing 66 edges...
# Instance 153: Custom distance 2.7085 <= DP distance 2.7085.
#
# Instance 154: Processing 66 edges...
# Instance 154: Custom distance 2.7096 <= DP distance 2.7096.
#
# Instance 155: Processing 66 edges...
# Instance 155: Custom distance 2.7254 <= DP distance 2.7254.
#
# Instance 156: Processing 66 edges...
# Instance 156: Custom distance 2.7289 <= DP distance 2.7289.
#
# Instance 157: Processing 66 edges...
# Instance 157: Custom distance 2.5199 <= DP distance 2.5199.
#
# Instance 158: Processing 66 edges...
# Instance 158: Custom distance 2.0875 <= DP distance 2.0875.
#
# Instance 159: Processing 66 edges...
# Instance 159: Custom distance 2.5966 <= DP distance 2.5966.
#
# Instance 160: Processing 66 edges...
# Instance 160: Custom distance 2.0456 <= DP distance 2.0456.
#
# Instance 161: Processing 66 edges...
# Instance 161: Custom distance 2.2788 <= DP distance 2.2788.
#
# Instance 162: Processing 66 edges...
# Instance 162: Custom distance 2.6854 <= DP distance 2.6854.
#
# Instance 163: Processing 66 edges...
# Instance 163: Custom distance 2.8238 <= DP distance 2.8238.
#
# Instance 164: Processing 66 edges...
# Instance 164: Custom distance 2.8561 <= DP distance 2.8561.
#
# Instance 165: Processing 66 edges...
# Instance 165: Custom distance 2.4845 <= DP distance 2.4845.
#
# Instance 166: Processing 66 edges...
# Instance 166: Custom distance 2.5269 <= DP distance 2.5269.
#
# Instance 167: Processing 66 edges...
# Instance 167: Custom distance 2.2765 <= DP distance 2.2765.
#
# Instance 168: Processing 66 edges...
# Instance 168: Custom distance 2.7306 <= DP distance 2.7306.
#
# Instance 169: Processing 66 edges...
# Instance 169: Custom distance 2.0767 <= DP distance 2.0767.
#
# Instance 170: Processing 66 edges...
# Instance 170: Custom distance 2.5934 <= DP distance 2.5934.
#
# Instance 171: Processing 66 edges...
# Instance 171: Custom distance 2.5301 <= DP distance 2.5301.
#
# Instance 172: Processing 66 edges...
# Instance 172: Custom distance 2.2909 <= DP distance 2.2909.
#
# Instance 173: Processing 66 edges...
# Instance 173: Custom distance 2.5831 <= DP distance 2.5831.
#
# Instance 174: Processing 66 edges...
# Instance 174: Custom distance 2.3807 <= DP distance 2.3807.
#
# Instance 175: Processing 66 edges...
# Instance 175: Custom distance 2.3201 <= DP distance 2.3201.
#
# Instance 176: Processing 66 edges...
# Instance 176: Custom distance 1.9489 <= DP distance 1.9489.
#
# Instance 177: Processing 66 edges...
# Instance 177: Custom distance 3.3341 <= DP distance 3.3341.
#
# Instance 178: Processing 66 edges...
# Instance 178: Custom distance 3.0678 <= DP distance 3.0678.
#
# Instance 179: Processing 66 edges...
# Instance 179: Custom distance 2.4161 <= DP distance 2.4161.
#
# Instance 180: Processing 66 edges...
# Instance 180: Custom distance 2.6890 <= DP distance 2.6890.
#
# Instance 181: Processing 66 edges...
# Instance 181: Custom distance 2.4788 <= DP distance 2.4788.
#
# Instance 182: Processing 66 edges...
# Instance 182: Custom distance 2.9786 <= DP distance 2.9786.
#
# Instance 183: Processing 66 edges...
# Instance 183: Custom distance 2.1253 <= DP distance 2.1253.
#
# Instance 184: Processing 66 edges...
# Instance 184: Custom distance 2.4123 <= DP distance 2.4123.
#
# Instance 185: Processing 66 edges...
# Instance 185: Custom distance 1.9730 <= DP distance 1.9730.
#
# Instance 186: Processing 66 edges...
# Instance 186: Custom distance 2.5460 <= DP distance 2.5460.
#
# Instance 187: Processing 66 edges...
# Instance 187: Custom distance 2.1652 <= DP distance 2.1652.
#
# Instance 188: Processing 66 edges...
# Instance 188: Custom distance 2.6218 <= DP distance 2.6218.
#
# Instance 189: Processing 66 edges...
# Instance 189: Custom distance 2.3716 <= DP distance 2.3716.
#
# Instance 190: Processing 66 edges...
# Instance 190: Custom distance 2.6970 <= DP distance 2.6970.
#
# Instance 191: Processing 66 edges...
# Instance 191: Custom distance 2.7406 <= DP distance 2.7406.
#
# Instance 192: Processing 66 edges...
# Instance 192: Custom distance 2.1287 <= DP distance 2.1287.
#
# Instance 193: Processing 66 edges...
# Instance 193: Custom distance 2.5223 <= DP distance 2.5223.
#
# Instance 194: Processing 66 edges...
# Instance 194: Custom distance 2.2658 <= DP distance 2.2658.
#
# Instance 195: Processing 66 edges...
# Instance 195: Custom distance 2.2271 <= DP distance 2.2271.
#
# Instance 196: Processing 66 edges...
# Instance 196: Custom distance 2.2040 <= DP distance 2.2040.
#
# Instance 197: Processing 66 edges...
# Instance 197: Custom distance 2.2002 <= DP distance 2.2002.
#
# Instance 198: Processing 66 edges...
# Instance 198: Custom distance 2.5535 <= DP distance 2.5535.
#
# Instance 199: Processing 66 edges...
# Instance 199: Custom distance 2.2960 <= DP distance 2.2960.
#
# Instance 200: Processing 66 edges...
# Instance 200: Custom distance 2.5464 <= DP distance 2.5464.
#
# Instance 201: Processing 66 edges...
# Instance 201: Custom distance 2.7653 <= DP distance 2.7653.
#
# Instance 202: Processing 66 edges...
# Instance 202: Custom distance 2.4947 <= DP distance 2.4947.
#
# Instance 203: Processing 66 edges...
# Instance 203: Custom distance 2.1710 <= DP distance 2.1710.
#
# Instance 204: Processing 66 edges...
# Instance 204: Custom distance 2.6131 <= DP distance 2.6131.
#
# Instance 205: Processing 66 edges...
# Instance 205: Custom distance 2.4737 <= DP distance 2.4737.
#
# Instance 206: Processing 66 edges...
# Instance 206: Custom distance 2.1865 <= DP distance 2.1865.
#
# Instance 207: Processing 66 edges...
# Instance 207: Custom distance 2.3605 <= DP distance 2.3605.
#
# Instance 208: Processing 66 edges...
# Instance 208: Custom distance 2.3958 <= DP distance 2.3958.
#
# Instance 209: Processing 66 edges...
# Instance 209: Custom distance 2.9402 <= DP distance 2.9402.
#
# Instance 210: Processing 66 edges...
# Instance 210: Custom distance 2.6867 <= DP distance 2.6867.
#
# Instance 211: Processing 66 edges...
# Instance 211: Custom distance 1.9846 <= DP distance 1.9846.
#
# Instance 212: Processing 66 edges...
# Instance 212: Custom distance 2.7113 <= DP distance 2.7113.
#
# Instance 213: Processing 66 edges...
# Instance 213: Custom distance 2.0905 <= DP distance 2.0905.
#
# Instance 214: Processing 66 edges...
# Instance 214: Custom distance 2.3841 <= DP distance 2.3841.
#
# Instance 215: Processing 66 edges...
# Instance 215: Custom distance 2.2223 <= DP distance 2.2223.
#
# Instance 216: Processing 66 edges...
# Instance 216: Custom distance 2.3002 <= DP distance 2.3002.
#
# Instance 217: Processing 66 edges...
# Instance 217: Custom distance 2.1876 <= DP distance 2.1876.
#
# Instance 218: Processing 66 edges...
# Instance 218: Custom distance 2.2065 <= DP distance 2.2065.
#
# Instance 219: Processing 66 edges...
# Instance 219: Custom distance 2.5635 <= DP distance 2.5635.
#
# Instance 220: Processing 66 edges...
# Instance 220: Custom distance 2.7618 <= DP distance 2.7618.
#
# Instance 221: Processing 66 edges...
# Instance 221: Custom distance 2.5089 <= DP distance 2.5089.
#
# Instance 222: Processing 66 edges...
# Instance 222: Custom distance 2.7996 <= DP distance 2.7996.
#
# Instance 223: Processing 66 edges...
# Instance 223: Custom distance 2.1103 <= DP distance 2.1103.
#
# Instance 224: Processing 66 edges...
# Instance 224: Custom distance 2.6182 <= DP distance 2.6182.
#
# Instance 225: Processing 66 edges...
# Instance 225: Custom distance 2.2437 <= DP distance 2.2437.
#
# Instance 226: Processing 66 edges...
# Instance 226: Custom distance 2.7913 <= DP distance 2.7913.
#
# Instance 227: Processing 66 edges...
# Instance 227: Custom distance 2.5443 <= DP distance 2.5443.
#
# Instance 228: Processing 66 edges...
# Instance 228: Custom distance 2.4606 <= DP distance 2.4606.
#
# Instance 229: Processing 66 edges...
# Instance 229: Custom distance 2.7842 <= DP distance 2.7842.
#
# Instance 230: Processing 66 edges...
# Instance 230: Custom distance 2.6160 <= DP distance 2.6160.
#
# Instance 231: Processing 66 edges...
# Instance 231: Custom distance 2.2735 <= DP distance 2.2735.
#
# Instance 232: Processing 66 edges...
# Instance 232: Custom distance 2.4015 <= DP distance 2.4015.
#
# Instance 233: Processing 66 edges...
# Instance 233: Custom distance 2.6207 <= DP distance 2.6207.
#
# Instance 234: Processing 66 edges...
# Instance 234: Custom distance 1.8897 <= DP distance 1.8897.
#
# Instance 235: Processing 66 edges...
# Instance 235: Custom distance 2.0327 <= DP distance 2.0327.
#
# Instance 236: Processing 66 edges...
# Instance 236: Custom distance 2.5366 <= DP distance 2.5366.
#
# Instance 237: Processing 66 edges...
# Instance 237: Custom distance 2.4937 <= DP distance 2.4937.
#
# Instance 238: Processing 66 edges...
# Instance 238: Custom distance 2.3487 <= DP distance 2.3487.
#
# Instance 239: Processing 66 edges...
# Instance 239: Custom distance 2.6476 <= DP distance 2.6476.
#
# Instance 240: Processing 66 edges...
# Instance 240: Custom distance 2.2691 <= DP distance 2.2691.
#
# Instance 241: Processing 66 edges...
# Instance 241: Custom distance 2.6775 <= DP distance 2.6775.
#
# Instance 242: Processing 66 edges...
# Instance 242: Custom distance 2.2917 <= DP distance 2.2917.
#
# Instance 243: Processing 66 edges...
# Instance 243: Custom distance 2.1885 <= DP distance 2.1885.
#
# Instance 244: Processing 66 edges...
# Instance 244: Custom distance 2.2426 <= DP distance 2.2426.
#
# Instance 245: Processing 66 edges...
# Instance 245: Custom distance 2.7437 <= DP distance 2.7437.
#
# Instance 246: Processing 66 edges...
# Instance 246: Custom distance 3.0555 <= DP distance 3.0555.
#
# Instance 247: Processing 66 edges...
# Instance 247: Custom distance 2.1694 <= DP distance 2.1694.
#
# Instance 248: Processing 66 edges...
# Instance 248: Custom distance 2.7992 <= DP distance 2.7992.
#
# Instance 249: Processing 66 edges...
# Instance 249: Custom distance 2.6850 <= DP distance 2.6850.
#
# Instance 250: Processing 66 edges...
# Instance 250: Custom distance 2.5429 <= DP distance 2.5429.
#
# Instance 251: Processing 66 edges...
# Instance 251: Custom distance 2.5349 <= DP distance 2.5349.
#
# Instance 252: Processing 66 edges...
# Instance 252: Custom distance 2.8559 <= DP distance 2.8559.
#
# Instance 253: Processing 66 edges...
# Instance 253: Custom distance 2.2294 <= DP distance 2.2294.
#
# Instance 254: Processing 66 edges...
# Instance 254: Custom distance 2.4513 <= DP distance 2.4513.
#
# Instance 255: Processing 66 edges...
# Instance 255: Custom distance 2.8520 <= DP distance 2.8520.
#
# Instance 256: Processing 66 edges...
# Instance 256: Custom distance 2.3485 <= DP distance 2.3485.
#
# Instance 257: Processing 66 edges...
# Instance 257: Custom distance 2.6758 <= DP distance 2.6758.
#
# Instance 258: Processing 66 edges...
# Instance 258: Custom distance 2.3362 <= DP distance 2.3362.
#
# Instance 259: Processing 66 edges...
# Instance 259: Custom distance 2.2863 <= DP distance 2.2863.
#
# Instance 260: Processing 66 edges...
# Instance 260: Custom distance 2.0332 <= DP distance 2.0332.
#
# Instance 261: Processing 66 edges...
# Instance 261: Custom distance 1.7332 <= DP distance 1.7332.
#
# Instance 262: Processing 66 edges...
# Instance 262: Custom distance 2.5614 <= DP distance 2.5614.
#
# Instance 263: Processing 66 edges...
# Instance 263: Custom distance 2.5869 <= DP distance 2.5869.
#
# Instance 264: Processing 66 edges...
# Instance 264: Custom distance 1.8032 <= DP distance 1.8032.
#
# Instance 265: Processing 66 edges...
# Instance 265: Custom distance 2.7448 <= DP distance 2.7448.
#
# Instance 266: Processing 66 edges...
# Instance 266: Custom distance 2.5326 <= DP distance 2.5326.
#
# Instance 267: Processing 66 edges...
# Instance 267: Custom distance 2.5887 <= DP distance 2.5887.
#
# Instance 268: Processing 66 edges...
# Instance 268: Custom distance 2.6797 <= DP distance 2.6797.
#
# Instance 269: Processing 66 edges...
# Instance 269: Custom distance 2.3973 <= DP distance 2.3973.
#
# Instance 270: Processing 66 edges...
# Instance 270: Custom distance 2.2927 <= DP distance 2.2927.
#
# Instance 271: Processing 66 edges...
# Instance 271: Custom distance 2.3813 <= DP distance 2.3813.
#
# Instance 272: Processing 66 edges...
# Instance 272: Custom distance 2.3648 <= DP distance 2.3648.
#
# Instance 273: Processing 66 edges...
# Instance 273: Custom distance 2.5210 <= DP distance 2.5210.
#
# Instance 274: Processing 66 edges...
# Instance 274: Custom distance 2.3983 <= DP distance 2.3983.
#
# Instance 275: Processing 66 edges...
# Instance 275: Custom distance 3.0055 <= DP distance 3.0055.
#
# Instance 276: Processing 66 edges...
# Instance 276: Custom distance 2.7428 <= DP distance 2.7428.
#
# Instance 277: Processing 66 edges...
# Instance 277: Custom distance 2.4759 <= DP distance 2.4759.
#
# Instance 278: Processing 66 edges...
# Instance 278: Custom distance 2.2268 <= DP distance 2.2268.
#
# Instance 279: Processing 66 edges...
# Instance 279: Custom distance 2.5844 <= DP distance 2.5844.
#
# Instance 280: Processing 66 edges...
# Instance 280: Custom distance 2.7044 <= DP distance 2.7044.
#
# Instance 281: Processing 66 edges...
# Instance 281: Custom distance 2.3666 <= DP distance 2.3666.
#
# Instance 282: Processing 66 edges...
# Instance 282: Custom distance 1.7956 <= DP distance 1.7956.
#
# Instance 283: Processing 66 edges...
# Instance 283: Custom distance 2.4758 <= DP distance 2.4758.
#
# Instance 284: Processing 66 edges...
# Instance 284: Custom distance 2.1791 <= DP distance 2.1791.
#
# Instance 285: Processing 66 edges...
# Instance 285: Custom distance 2.2624 <= DP distance 2.2624.
#
# Instance 286: Processing 66 edges...
# Instance 286: Custom distance 2.5183 <= DP distance 2.5183.
#
# Instance 287: Processing 66 edges...
# Instance 287: Custom distance 2.6099 <= DP distance 2.6099.
#
# Instance 288: Processing 66 edges...
# Instance 288: Custom distance 2.8181 <= DP distance 2.8181.
#
# Instance 289: Processing 66 edges...
# Instance 289: Custom distance 2.6322 <= DP distance 2.6322.
#
# Instance 290: Processing 66 edges...
# Instance 290: Custom distance 2.2723 <= DP distance 2.2723.
#
# Instance 291: Processing 66 edges...
# Instance 291: Custom distance 1.9605 <= DP distance 1.9605.
#
# Instance 292: Processing 66 edges...
# Instance 292: Custom distance 2.7878 <= DP distance 2.7878.
#
# Instance 293: Processing 66 edges...
# Instance 293: Custom distance 2.1256 <= DP distance 2.1256.
#
# Instance 294: Processing 66 edges...
# Instance 294: Custom distance 2.1947 <= DP distance 2.1947.
#
# Instance 295: Processing 66 edges...
# Instance 295: Custom distance 2.4767 <= DP distance 2.4767.
#
# Instance 296: Processing 66 edges...
# Instance 296: Custom distance 2.8453 <= DP distance 2.8453.
#
# Instance 297: Processing 66 edges...
# Instance 297: Custom distance 2.2098 <= DP distance 2.2098.
#
# Instance 298: Processing 66 edges...
# Instance 298: Custom distance 2.7627 <= DP distance 2.7627.
#
# Instance 299: Processing 66 edges...
# Instance 299: Custom distance 2.7242 <= DP distance 2.7242.
#
# Instance 300: Processing 66 edges...
# Instance 300: Custom distance 2.2946 <= DP distance 2.2946.
#
# Instance 301: Processing 66 edges...
# Instance 301: Custom distance 2.4840 <= DP distance 2.4840.
#
# Instance 302: Processing 66 edges...
# Instance 302: Custom distance 2.0616 <= DP distance 2.0616.
#
# Instance 303: Processing 66 edges...
# Instance 303: Custom distance 2.4527 <= DP distance 2.4527.
#
# Instance 304: Processing 66 edges...
# Instance 304: Custom distance 2.6635 <= DP distance 2.6635.
#
# Instance 305: Processing 66 edges...
# Instance 305: Custom distance 2.2601 <= DP distance 2.2601.
#
# Instance 306: Processing 66 edges...
# Instance 306: Custom distance 2.4556 <= DP distance 2.4556.
#
# Instance 307: Processing 66 edges...
# Instance 307: Custom distance 3.1901 <= DP distance 3.1901.
#
# Instance 308: Processing 66 edges...
# Instance 308: Custom distance 1.9608 <= DP distance 1.9608.
#
# Instance 309: Processing 66 edges...
# Instance 309: Custom distance 2.3983 <= DP distance 2.3983.
#
# Instance 310: Processing 66 edges...
# Instance 310: Custom distance 2.4022 <= DP distance 2.4022.
#
# Instance 311: Processing 66 edges...
# Instance 311: Custom distance 2.3282 <= DP distance 2.3282.
#
# Instance 312: Processing 66 edges...
# Instance 312: Custom distance 2.5473 <= DP distance 2.5473.
#
# Instance 313: Processing 66 edges...
# Instance 313: Custom distance 2.9993 <= DP distance 2.9993.
#
# Instance 314: Processing 66 edges...
# Instance 314: Custom distance 1.7259 <= DP distance 1.7259.
#
# Instance 315: Processing 66 edges...
# Instance 315: Custom distance 2.4359 <= DP distance 2.4359.
#
# Instance 316: Processing 66 edges...
# Instance 316: Custom distance 2.5741 <= DP distance 2.5741.
#
# Instance 317: Processing 66 edges...
# Instance 317: Custom distance 2.5639 <= DP distance 2.5639.
#
# Instance 318: Processing 66 edges...
# Instance 318: Custom distance 2.1960 <= DP distance 2.1960.
#
# Instance 319: Processing 66 edges...
# Instance 319: Custom distance 2.4852 <= DP distance 2.4852.
#
# Instance 320: Processing 66 edges...
# Instance 320: Custom distance 2.0073 <= DP distance 2.0073.
#
# Instance 321: Processing 66 edges...
# Instance 321: Custom distance 2.7474 <= DP distance 2.7474.
#
# Instance 322: Processing 66 edges...
# Instance 322: Custom distance 2.1753 <= DP distance 2.1753.
#
# Instance 323: Processing 66 edges...
# Instance 323: Custom distance 2.4508 <= DP distance 2.4508.
#
# Instance 324: Processing 66 edges...
# Instance 324: Custom distance 2.7432 <= DP distance 2.7432.
#
# Instance 325: Processing 66 edges...
# Instance 325: Custom distance 2.7679 <= DP distance 2.7679.
#
# Instance 326: Processing 66 edges...
# Instance 326: Custom distance 2.8661 <= DP distance 2.8661.
#
# Instance 327: Processing 66 edges...
# Instance 327: Custom distance 2.5340 <= DP distance 2.5340.
#
# Instance 328: Processing 66 edges...
# Instance 328: Custom distance 2.6935 <= DP distance 2.6935.
#
# Instance 329: Processing 66 edges...
# Instance 329: Custom distance 2.5386 <= DP distance 2.5386.
#
# Instance 330: Processing 66 edges...
# Instance 330: Custom distance 2.3037 <= DP distance 2.3037.
#
# Instance 331: Processing 66 edges...
# Instance 331: Custom distance 2.6308 <= DP distance 2.6308.
#
# Instance 332: Processing 66 edges...
# Instance 332: Custom distance 2.1623 <= DP distance 2.1623.
#
# Instance 333: Processing 66 edges...
# Instance 333: Custom distance 2.4887 <= DP distance 2.4887.
#
# Instance 334: Processing 66 edges...
# Instance 334: Custom distance 2.6752 <= DP distance 2.6752.
#
# Instance 335: Processing 66 edges...
# Instance 335: Custom distance 1.7646 <= DP distance 1.7646.
#
# Instance 336: Processing 66 edges...
# Instance 336: Custom distance 2.5234 <= DP distance 2.5234.
#
# Instance 337: Processing 66 edges...
# Instance 337: Custom distance 2.9166 <= DP distance 2.9166.
#
# Instance 338: Processing 66 edges...
# Instance 338: Custom distance 2.5996 <= DP distance 2.5996.
#
# Instance 339: Processing 66 edges...
# Instance 339: Custom distance 3.2011 <= DP distance 3.2011.
#
# Instance 340: Processing 66 edges...
# Instance 340: Custom distance 2.6545 <= DP distance 2.6545.
#
# Instance 341: Processing 66 edges...
# Instance 341: Custom distance 2.3922 <= DP distance 2.3922.
#
# Instance 342: Processing 66 edges...
# Instance 342: Custom distance 2.1602 <= DP distance 2.1602.
#
# Instance 343: Processing 66 edges...
# Instance 343: Custom distance 2.3692 <= DP distance 2.3692.
#
# Instance 344: Processing 66 edges...
# Instance 344: Custom distance 1.7793 <= DP distance 1.7793.
#
# Instance 345: Processing 66 edges...
# Instance 345: Custom distance 2.8962 <= DP distance 2.8962.
#
# Instance 346: Processing 66 edges...
# Instance 346: Custom distance 2.5069 <= DP distance 2.5069.
#
# Instance 347: Processing 66 edges...
# Instance 347: Custom distance 2.7953 <= DP distance 2.7953.
#
# Instance 348: Processing 66 edges...
# Instance 348: Custom distance 2.2382 <= DP distance 2.2382.
#
# Instance 349: Processing 66 edges...
# Instance 349: Custom distance 2.0974 <= DP distance 2.0974.
#
# Instance 350: Processing 66 edges...
# Instance 350: Custom distance 2.4216 <= DP distance 2.4216.
#
# Instance 351: Processing 66 edges...
# Instance 351: Custom distance 2.2619 <= DP distance 2.2619.
#
# Instance 352: Processing 66 edges...
# Instance 352: Custom distance 2.7350 <= DP distance 2.7350.
#
# Instance 353: Processing 66 edges...
# Instance 353: Custom distance 2.5930 <= DP distance 2.5930.
#
# Instance 354: Processing 66 edges...
# Instance 354: Custom distance 1.7472 <= DP distance 1.7472.
#
# Instance 355: Processing 66 edges...
# Instance 355: Custom distance 2.6453 <= DP distance 2.6453.
#
# Instance 356: Processing 66 edges...
# Instance 356: Custom distance 2.2091 <= DP distance 2.2091.
#
# Instance 357: Processing 66 edges...
# Instance 357: Custom distance 1.8641 <= DP distance 1.8641.
#
# Instance 358: Processing 66 edges...
# Instance 358: Custom distance 2.0884 <= DP distance 2.0884.
#
# Instance 359: Processing 66 edges...
# Instance 359: Custom distance 2.8826 <= DP distance 2.8826.
#
# Instance 360: Processing 66 edges...
# Instance 360: Custom distance 2.3392 <= DP distance 2.3392.
#
# Instance 361: Processing 66 edges...
# Instance 361: Custom distance 2.8399 <= DP distance 2.8399.
#
# Instance 362: Processing 66 edges...
# Instance 362: Custom distance 2.4861 <= DP distance 2.4861.
#
# Instance 363: Processing 66 edges...
# Instance 363: Custom distance 2.6896 <= DP distance 2.6896.
#
# Instance 364: Processing 66 edges...
# Instance 364: Custom distance 3.0149 <= DP distance 3.0149.
#
# Instance 365: Processing 66 edges...
# Instance 365: Custom distance 3.0065 <= DP distance 3.0065.
#
# Instance 366: Processing 66 edges...
# Instance 366: Custom distance 2.0927 <= DP distance 2.0927.
#
# Instance 367: Processing 66 edges...
# Instance 367: Custom distance 2.4051 <= DP distance 2.4051.
#
# Instance 368: Processing 66 edges...
# Instance 368: Custom distance 2.8536 <= DP distance 2.8536.
#
# Instance 369: Processing 66 edges...
# Instance 369: Custom distance 2.9881 <= DP distance 2.9881.
#
# Instance 370: Processing 66 edges...
# Instance 370: Custom distance 2.6249 <= DP distance 2.6249.
#
# Instance 371: Processing 66 edges...
# Instance 371: Custom distance 2.4388 <= DP distance 2.4388.
#
# Instance 372: Processing 66 edges...
# Instance 372: Custom distance 2.1830 <= DP distance 2.1830.
#
# Instance 373: Processing 66 edges...
# Instance 373: Custom distance 2.4358 <= DP distance 2.4358.
#
# Instance 374: Processing 66 edges...
# Instance 374: Custom distance 1.9869 <= DP distance 1.9869.
#
# Instance 375: Processing 66 edges...
# Instance 375: Custom distance 2.5652 <= DP distance 2.5652.
#
# Instance 376: Processing 66 edges...
# Instance 376: Custom distance 2.4392 <= DP distance 2.4392.
#
# Instance 377: Processing 66 edges...
# Instance 377: Custom distance 2.5183 <= DP distance 2.5183.
#
# Instance 378: Processing 66 edges...
# Instance 378: Custom distance 2.3049 <= DP distance 2.3049.
#
# Instance 379: Processing 66 edges...
# Instance 379: Custom distance 2.7823 <= DP distance 2.7823.
#
# Instance 380: Processing 66 edges...
# Instance 380: Custom distance 2.4690 <= DP distance 2.4690.
#
# Instance 381: Processing 66 edges...
# Instance 381: Custom distance 2.5933 <= DP distance 2.5933.
#
# Instance 382: Processing 66 edges...
# Instance 382: Custom distance 2.4177 <= DP distance 2.4177.
#
# Instance 383: Processing 66 edges...
# Instance 383: Custom distance 2.1154 <= DP distance 2.1154.
#
# Instance 384: Processing 66 edges...
# Instance 384: Custom distance 1.9797 <= DP distance 1.9797.
#
# Instance 385: Processing 66 edges...
# Instance 385: Custom distance 2.4551 <= DP distance 2.4551.
#
# Instance 386: Processing 66 edges...
# Instance 386: Custom distance 2.3573 <= DP distance 2.3573.
#
# Instance 387: Processing 66 edges...
# Instance 387: Custom distance 2.4248 <= DP distance 2.4248.
#
# Instance 388: Processing 66 edges...
# Instance 388: Custom distance 2.1174 <= DP distance 2.1174.
#
# Instance 389: Processing 66 edges...
# Instance 389: Custom distance 2.1344 <= DP distance 2.1344.
#
# Instance 390: Processing 66 edges...
# Instance 390: Custom distance 2.0296 <= DP distance 2.0296.
#
# Instance 391: Processing 66 edges...
# Instance 391: Custom distance 2.2399 <= DP distance 2.2399.
#
# Instance 392: Processing 66 edges...
# Instance 392: Custom distance 2.7987 <= DP distance 2.7987.
#
# Instance 393: Processing 66 edges...
# Instance 393: Custom distance 2.6130 <= DP distance 2.6130.
#
# Instance 394: Processing 66 edges...
# Instance 394: Custom distance 2.6161 <= DP distance 2.6161.
#
# Instance 395: Processing 66 edges...
# Instance 395: Custom distance 2.2065 <= DP distance 2.2065.
#
# Instance 396: Processing 66 edges...
# Instance 396: Custom distance 2.4401 <= DP distance 2.4401.
#
# Instance 397: Processing 66 edges...
# Instance 397: Custom distance 2.1757 <= DP distance 2.1757.
#
# Instance 398: Processing 66 edges...
# Instance 398: Custom distance 2.4606 <= DP distance 2.4606.
#
# Instance 399: Processing 66 edges...
# Instance 399: Custom distance 2.2905 <= DP distance 2.2905.
#
# Instance 400: Processing 66 edges...
# Instance 400: Custom distance 2.2069 <= DP distance 2.2069.
#
# Instance 401: Processing 66 edges...
# Instance 401: Custom distance 2.5509 <= DP distance 2.5509.
#
# Instance 402: Processing 66 edges...
# Instance 402: Custom distance 2.0806 <= DP distance 2.0806.
#
# Instance 403: Processing 66 edges...
# Instance 403: Custom distance 2.8212 <= DP distance 2.8212.
#
# Instance 404: Processing 66 edges...
# Instance 404: Custom distance 2.7931 <= DP distance 2.7931.
#
# Instance 405: Processing 66 edges...
# Instance 405: Custom distance 2.0717 <= DP distance 2.0717.
#
# Instance 406: Processing 66 edges...
# Instance 406: Custom distance 2.4062 <= DP distance 2.4062.
#
# Instance 407: Processing 66 edges...
# Instance 407: Custom distance 2.7624 <= DP distance 2.7624.
#
# Instance 408: Processing 66 edges...
# Instance 408: Custom distance 2.7245 <= DP distance 2.7245.
#
# Instance 409: Processing 66 edges...
# Instance 409: Custom distance 2.1653 <= DP distance 2.1653.
#
# Instance 410: Processing 66 edges...
# Instance 410: Custom distance 2.0577 <= DP distance 2.0577.
#
# Instance 411: Processing 66 edges...
# Instance 411: Custom distance 2.6910 <= DP distance 2.6910.
#
# Instance 412: Processing 66 edges...
# Instance 412: Custom distance 2.8258 <= DP distance 2.8258.
#
# Instance 413: Processing 66 edges...
# Instance 413: Custom distance 2.6903 <= DP distance 2.6903.
#
# Instance 414: Processing 66 edges...
# Instance 414: Custom distance 2.9004 <= DP distance 2.9004.
#
# Instance 415: Processing 66 edges...
# Instance 415: Custom distance 2.5860 <= DP distance 2.5860.
#
# Instance 416: Processing 66 edges...
# Instance 416: Custom distance 2.9768 <= DP distance 2.9768.
#
# Instance 417: Processing 66 edges...
# Instance 417: Custom distance 2.9877 <= DP distance 2.9877.
#
# Instance 418: Processing 66 edges...
# Instance 418: Custom distance 3.0519 <= DP distance 3.0519.
#
# Instance 419: Processing 66 edges...
# Instance 419: Custom distance 2.4978 <= DP distance 2.4978.
#
# Instance 420: Processing 66 edges...
# Instance 420: Custom distance 2.1733 <= DP distance 2.1733.
#
# Instance 421: Processing 66 edges...
# Instance 421: Custom distance 2.6194 <= DP distance 2.6194.
#
# Instance 422: Processing 66 edges...
# Instance 422: Custom distance 2.5084 <= DP distance 2.5084.
#
# Instance 423: Processing 66 edges...
# Instance 423: Custom distance 2.5212 <= DP distance 2.5212.
#
# Instance 424: Processing 66 edges...
# Instance 424: Custom distance 2.6320 <= DP distance 2.6320.
#
# Instance 425: Processing 66 edges...
# Instance 425: Custom distance 2.6332 <= DP distance 2.6332.
#
# Instance 426: Processing 66 edges...
# Instance 426: Custom distance 2.2320 <= DP distance 2.2320.
#
# Instance 427: Processing 66 edges...
# Instance 427: Custom distance 1.8020 <= DP distance 1.8020.
#
# Instance 428: Processing 66 edges...
# Instance 428: Custom distance 2.0305 <= DP distance 2.0305.
#
# Instance 429: Processing 66 edges...
# Instance 429: Custom distance 2.5963 <= DP distance 2.5963.
#
# Instance 430: Processing 66 edges...
# Instance 430: Custom distance 2.7241 <= DP distance 2.7241.
#
# Instance 431: Processing 66 edges...
# Instance 431: Custom distance 2.3323 <= DP distance 2.3323.
#
# Instance 432: Processing 66 edges...
# Instance 432: Custom distance 2.6989 <= DP distance 2.6989.
#
# Instance 433: Processing 66 edges...
# Instance 433: Custom distance 3.1310 <= DP distance 3.1310.
#
# Instance 434: Processing 66 edges...
# Instance 434: Custom distance 2.4665 <= DP distance 2.4665.
#
# Instance 435: Processing 66 edges...
# Instance 435: Custom distance 2.7109 <= DP distance 2.7109.
#
# Instance 436: Processing 66 edges...
# Instance 436: Custom distance 2.0345 <= DP distance 2.0345.
#
# Instance 437: Processing 66 edges...
# Instance 437: Custom distance 1.9720 <= DP distance 1.9720.
#
# Instance 438: Processing 66 edges...
# Instance 438: Custom distance 2.3390 <= DP distance 2.3390.
#
# Instance 439: Processing 66 edges...
# Instance 439: Custom distance 2.6557 <= DP distance 2.6557.
#
# Instance 440: Processing 66 edges...
# Instance 440: Custom distance 2.6213 <= DP distance 2.6213.
#
# Instance 441: Processing 66 edges...
# Instance 441: Custom distance 2.4923 <= DP distance 2.4923.
#
# Instance 442: Processing 66 edges...
# Instance 442: Custom distance 2.3018 <= DP distance 2.3018.
#
# Instance 443: Processing 66 edges...
# Instance 443: Custom distance 2.1884 <= DP distance 2.1884.
#
# Instance 444: Processing 66 edges...
# Instance 444: Custom distance 2.2452 <= DP distance 2.2452.
#
# Instance 445: Processing 66 edges...
# Instance 445: Custom distance 2.5632 <= DP distance 2.5632.
#
# Instance 446: Processing 66 edges...
# Instance 446: Custom distance 1.9910 <= DP distance 1.9910.
#
# Instance 447: Processing 66 edges...
# Instance 447: Custom distance 2.5325 <= DP distance 2.5325.
#
# Instance 448: Processing 66 edges...
# Instance 448: Custom distance 2.2822 <= DP distance 2.2822.
#
# Instance 449: Processing 66 edges...
# Instance 449: Custom distance 2.4194 <= DP distance 2.4194.
#
# Instance 450: Processing 66 edges...
# Instance 450: Custom distance 2.6135 <= DP distance 2.6135.
#
# Instance 451: Processing 66 edges...
# Instance 451: Custom distance 3.1183 <= DP distance 3.1183.
#
# Instance 452: Processing 66 edges...
# Instance 452: Custom distance 2.5368 <= DP distance 2.5368.
#
# Instance 453: Processing 66 edges...
# Instance 453: Custom distance 2.5172 <= DP distance 2.5172.
#
# Instance 454: Processing 66 edges...
# Instance 454: Custom distance 2.3297 <= DP distance 2.3297.
#
# Instance 455: Processing 66 edges...
# Instance 455: Custom distance 2.4656 <= DP distance 2.4656.
#
# Instance 456: Processing 66 edges...
# Instance 456: Custom distance 2.8591 <= DP distance 2.8591.
#
# Instance 457: Processing 66 edges...
# Instance 457: Custom distance 2.1489 <= DP distance 2.1489.
#
# Instance 458: Processing 66 edges...
# Instance 458: Custom distance 2.8476 <= DP distance 2.8476.
#
# Instance 459: Processing 66 edges...
# Instance 459: Custom distance 2.3317 <= DP distance 2.3317.
#
# Instance 460: Processing 66 edges...
# Instance 460: Custom distance 2.2477 <= DP distance 2.2477.
#
# Instance 461: Processing 66 edges...
# Instance 461: Custom distance 2.9849 <= DP distance 2.9849.
#
# Instance 462: Processing 66 edges...
# Instance 462: Custom distance 2.5100 <= DP distance 2.5100.
#
# Instance 463: Processing 66 edges...
# Instance 463: Custom distance 2.1631 <= DP distance 2.1631.
#
# Instance 464: Processing 66 edges...
# Instance 464: Custom distance 2.4061 <= DP distance 2.4061.
#
# Instance 465: Processing 66 edges...
# Instance 465: Custom distance 1.9214 <= DP distance 1.9214.
#
# Instance 466: Processing 66 edges...
# Instance 466: Custom distance 2.9839 <= DP distance 2.9839.
#
# Instance 467: Processing 66 edges...
# Instance 467: Custom distance 2.0659 <= DP distance 2.0659.
#
# Instance 468: Processing 66 edges...
# Instance 468: Custom distance 2.1612 <= DP distance 2.1612.
#
# Instance 469: Processing 66 edges...
# Instance 469: Custom distance 2.6059 <= DP distance 2.6059.
#
# Instance 470: Processing 66 edges...
# Instance 470: Custom distance 2.5858 <= DP distance 2.5858.
#
# Instance 471: Processing 66 edges...
# Instance 471: Custom distance 2.5710 <= DP distance 2.5710.
#
# Instance 472: Processing 66 edges...
# Instance 472: Custom distance 2.4743 <= DP distance 2.4743.
#
# Instance 473: Processing 66 edges...
# Instance 473: Custom distance 2.6899 <= DP distance 2.6899.
#
# Instance 474: Processing 66 edges...
# Instance 474: Custom distance 2.0687 <= DP distance 2.0687.
#
# Instance 475: Processing 66 edges...
# Instance 475: Custom distance 2.3514 <= DP distance 2.3514.
#
# Instance 476: Processing 66 edges...
# Instance 476: Custom distance 2.7392 <= DP distance 2.7392.
#
# Instance 477: Processing 66 edges...
# Instance 477: Custom distance 2.2113 <= DP distance 2.2113.
#
# Instance 478: Processing 66 edges...
# Instance 478: Custom distance 2.0925 <= DP distance 2.0925.
#
# Instance 479: Processing 66 edges...
# Instance 479: Custom distance 2.6438 <= DP distance 2.6438.
#
# Instance 480: Processing 66 edges...
# Instance 480: Custom distance 2.3200 <= DP distance 2.3200.
#
# Instance 481: Processing 66 edges...
# Instance 481: Custom distance 2.6183 <= DP distance 2.6183.
#
# Instance 482: Processing 66 edges...
# Instance 482: Custom distance 2.6993 <= DP distance 2.6993.
#
# Instance 483: Processing 66 edges...
# Instance 483: Custom distance 2.3716 <= DP distance 2.3716.
#
# Instance 484: Processing 66 edges...
# Instance 484: Custom distance 2.4246 <= DP distance 2.4246.
#
# Instance 485: Processing 66 edges...
# Instance 485: Custom distance 2.2551 <= DP distance 2.2551.
#
# Instance 486: Processing 66 edges...
# Instance 486: Custom distance 2.8509 <= DP distance 2.8509.
#
# Instance 487: Processing 66 edges...
# Instance 487: Custom distance 2.2335 <= DP distance 2.2335.
#
# Instance 488: Processing 66 edges...
# Instance 488: Custom distance 2.7439 <= DP distance 2.7439.
#
# Instance 489: Processing 66 edges...
# Instance 489: Custom distance 2.3630 <= DP distance 2.3630.
#
# Instance 490: Processing 66 edges...
# Instance 490: Custom distance 2.4260 <= DP distance 2.4260.
#
# Instance 491: Processing 66 edges...
# Instance 491: Custom distance 2.4621 <= DP distance 2.4621.
#
# Instance 492: Processing 66 edges...
# ...
#
# Instance 840: Processing 66 edges...
# Instance 840: Custom distance 3.0176 <= DP distance 3.0176.
#
# Instance 841: Processing 66 edges...
# Instance 841: Custom distance 2.5391 <= DP distance 2.5391.
#
# Instance 842: Processing 66 edges...
# Instance 842: Custom distance 2.5061 <= DP distance 2.5061.
#
# Instance 843: Processing 66 edges...
# Instance 843: Custom distance 2.8657 <= DP distance 2.8657.
#
# Instance 844: Processing 66 edges...
# Instance 844: Custom distance 1.9653 <= DP distance 1.9653.
#
# Instance 845: Processing 66 edges...
# Instance 845: Custom distance 2.7987 <= DP distance 2.7987.
#
# Instance 846: Processing 66 edges...
# Instance 846: Custom distance 2.4815 <= DP distance 2.4815.
#
# Instance 847: Processing 66 edges...
# Instance 847: Custom distance 2.9339 <= DP distance 2.9339.
#
# Instance 848: Processing 66 edges...
# Instance 848: Custom distance 2.0014 <= DP distance 2.0014.
#
# Instance 849: Processing 66 edges...
# Instance 849: Custom distance 2.1959 <= DP distance 2.1959.
#
# Instance 850: Processing 66 edges...
# Instance 850: Custom distance 2.8863 <= DP distance 2.8863.
#
# Instance 851: Processing 66 edges...
# Instance 851: Custom distance 2.4843 <= DP distance 2.4843.
#
# Instance 852: Processing 66 edges...
# Instance 852: Custom distance 2.3530 <= DP distance 2.3530.
#
# Instance 853: Processing 66 edges...
# Instance 853: Custom distance 2.0697 <= DP distance 2.0697.
#
# Instance 854: Processing 66 edges...
# Instance 854: Custom distance 2.7291 <= DP distance 2.7291.
#
# Instance 855: Processing 66 edges...
# Instance 855: Custom distance 2.5134 <= DP distance 2.5134.
#
# Instance 856: Processing 66 edges...
# Instance 856: Custom distance 2.2757 <= DP distance 2.2757.
#
# Instance 857: Processing 66 edges...
# Instance 857: Custom distance 2.1859 <= DP distance 2.1859.
#
# Instance 858: Processing 66 edges...
# Instance 858: Custom distance 2.6487 <= DP distance 2.6487.
#
# Instance 859: Processing 66 edges...
# Instance 859: Custom distance 2.4318 <= DP distance 2.4318.
#
# Instance 860: Processing 66 edges...
# Instance 860: Custom distance 1.9891 <= DP distance 1.9891.
#
# Instance 861: Processing 66 edges...
# Instance 861: Custom distance 2.2955 <= DP distance 2.2955.
#
# Instance 862: Processing 66 edges...
# Instance 862: Custom distance 2.1685 <= DP distance 2.1685.
#
# Instance 863: Processing 66 edges...
# Instance 863: Custom distance 2.1729 <= DP distance 2.1729.
#
# Instance 864: Processing 66 edges...
# Instance 864: Custom distance 2.5398 <= DP distance 2.5398.
#
# Instance 865: Processing 66 edges...
# Instance 865: Custom distance 2.2881 <= DP distance 2.2881.
#
# Instance 866: Processing 66 edges...
# Instance 866: Custom distance 2.6436 <= DP distance 2.6436.
#
# Instance 867: Processing 66 edges...
# Instance 867: Custom distance 2.7163 <= DP distance 2.7163.
#
# Instance 868: Processing 66 edges...
# Instance 868: Custom distance 2.2433 <= DP distance 2.2433.
#
# Instance 869: Processing 66 edges...
# Instance 869: Custom distance 2.3109 <= DP distance 2.3109.
#
# Instance 870: Processing 66 edges...
# Instance 870: Custom distance 2.0529 <= DP distance 2.0529.
#
# Instance 871: Processing 66 edges...
# Instance 871: Custom distance 2.6870 <= DP distance 2.6870.
#
# Instance 872: Processing 66 edges...
# Instance 872: Custom distance 2.4856 <= DP distance 2.4856.
#
# Instance 873: Processing 66 edges...
# Instance 873: Custom distance 1.8055 <= DP distance 1.8055.
#
# Instance 874: Processing 66 edges...
# Instance 874: Custom distance 2.1678 <= DP distance 2.1678.
#
# Instance 875: Processing 66 edges...
# Instance 875: Custom distance 2.1280 <= DP distance 2.1280.
#
# Instance 876: Processing 66 edges...
# Instance 876: Custom distance 2.0808 <= DP distance 2.0808.
#
# Instance 877: Processing 66 edges...
# Instance 877: Custom distance 2.4261 <= DP distance 2.4261.
#
# Instance 878: Processing 66 edges...
# Instance 878: Custom distance 2.6548 <= DP distance 2.6548.
#
# Instance 879: Processing 66 edges...
# Instance 879: Custom distance 2.0546 <= DP distance 2.0546.
#
# Instance 880: Processing 66 edges...
# Instance 880: Custom distance 2.6185 <= DP distance 2.6185.
#
# Instance 881: Processing 66 edges...
# Instance 881: Custom distance 2.4155 <= DP distance 2.4155.
#
# Instance 882: Processing 66 edges...
# Instance 882: Custom distance 2.6541 <= DP distance 2.6541.
#
# Instance 883: Processing 66 edges...
# Instance 883: Custom distance 1.8527 <= DP distance 1.8527.
#
# Instance 884: Processing 66 edges...
# Instance 884: Custom distance 2.7517 <= DP distance 2.7517.
#
# Instance 885: Processing 66 edges...
# Instance 885: Custom distance 2.4849 <= DP distance 2.4849.
#
# Instance 886: Processing 66 edges...
# Instance 886: Custom distance 2.6624 <= DP distance 2.6624.
#
# Instance 887: Processing 66 edges...
# Instance 887: Custom distance 2.6579 <= DP distance 2.6579.
#
# Instance 888: Processing 66 edges...
# Instance 888: Custom distance 2.8029 <= DP distance 2.8029.
#
# Instance 889: Processing 66 edges...
# Instance 889: Custom distance 2.5017 <= DP distance 2.5017.
#
# Instance 890: Processing 66 edges...
# Instance 890: Custom distance 2.4014 <= DP distance 2.4014.
#
# Instance 891: Processing 66 edges...
# Instance 891: Custom distance 2.7774 <= DP distance 2.7774.
#
# Instance 892: Processing 66 edges...
# Instance 892: Custom distance 2.3926 <= DP distance 2.3926.
#
# Instance 893: Processing 66 edges...
# Instance 893: Custom distance 2.3103 <= DP distance 2.3103.
#
# Instance 894: Processing 66 edges...
# Instance 894: Custom distance 1.9243 <= DP distance 1.9243.
#
# Instance 895: Processing 66 edges...
# Instance 895: Custom distance 2.2517 <= DP distance 2.2517.
#
# Instance 896: Processing 66 edges...
# Instance 896: Custom distance 3.0698 <= DP distance 3.0698.
#
# Instance 897: Processing 66 edges...
# Instance 897: Custom distance 2.9254 <= DP distance 2.9254.
#
# Instance 898: Processing 66 edges...
# Instance 898: Custom distance 2.2245 <= DP distance 2.2245.
#
# Instance 899: Processing 66 edges...
# Instance 899: Custom distance 2.5539 <= DP distance 2.5539.
#
# Instance 900: Processing 66 edges...
# Instance 900: Custom distance 2.3310 <= DP distance 2.3310.
#
# Instance 901: Processing 66 edges...
# Instance 901: Custom distance 2.8062 <= DP distance 2.8062.
#
# Instance 902: Processing 66 edges...
# Instance 902: Custom distance 2.2863 <= DP distance 2.2863.
#
# Instance 903: Processing 66 edges...
# Instance 903: Custom distance 2.6670 <= DP distance 2.6670.
#
# Instance 904: Processing 66 edges...
# Instance 904: Custom distance 2.8329 <= DP distance 2.8329.
#
# Instance 905: Processing 66 edges...
# Instance 905: Custom distance 2.5735 <= DP distance 2.5735.
#
# Instance 906: Processing 66 edges...
# Instance 906: Custom distance 2.9668 <= DP distance 2.9668.
#
# Instance 907: Processing 66 edges...
# Instance 907: Custom distance 2.5861 <= DP distance 2.5861.
#
# Instance 908: Processing 66 edges...
# Instance 908: Custom distance 2.4524 <= DP distance 2.4524.
#
# Instance 909: Processing 66 edges...
# Instance 909: Custom distance 2.1345 <= DP distance 2.1345.
#
# Instance 910: Processing 66 edges...
# Instance 910: Custom distance 2.3304 <= DP distance 2.3304.
#
# Instance 911: Processing 66 edges...
# Instance 911: Custom distance 2.6733 <= DP distance 2.6733.
#
# Instance 912: Processing 66 edges...
# Instance 912: Custom distance 2.1953 <= DP distance 2.1953.
#
# Instance 913: Processing 66 edges...
# Instance 913: Custom distance 3.2594 <= DP distance 3.2594.
#
# Instance 914: Processing 66 edges...
# Instance 914: Custom distance 2.1412 <= DP distance 2.1412.
#
# Instance 915: Processing 66 edges...
# Instance 915: Custom distance 2.6437 <= DP distance 2.6437.
#
# Instance 916: Processing 66 edges...
# Instance 916: Custom distance 2.9052 <= DP distance 2.9052.
#
# Instance 917: Processing 66 edges...
# Instance 917: Custom distance 2.0064 <= DP distance 2.0064.
#
# Instance 918: Processing 66 edges...
# Instance 918: Custom distance 1.9172 <= DP distance 1.9172.
#
# Instance 919: Processing 66 edges...
# Instance 919: Custom distance 3.1647 <= DP distance 3.1647.
#
# Instance 920: Processing 66 edges...
# Instance 920: Custom distance 3.1266 <= DP distance 3.1266.
#
# Instance 921: Processing 66 edges...
# Instance 921: Custom distance 2.5003 <= DP distance 2.5003.
#
# Instance 922: Processing 66 edges...
# Instance 922: Custom distance 2.7370 <= DP distance 2.7370.
#
# Instance 923: Processing 66 edges...
# Instance 923: Custom distance 2.4585 <= DP distance 2.4585.
#
# Instance 924: Processing 66 edges...
# Instance 924: Custom distance 1.8613 <= DP distance 1.8613.
#
# Instance 925: Processing 66 edges...
# Instance 925: Custom distance 2.9063 <= DP distance 2.9063.
#
# Instance 926: Processing 66 edges...
# Instance 926: Custom distance 2.7089 <= DP distance 2.7089.
#
# Instance 927: Processing 66 edges...
# Instance 927: Custom distance 2.3060 <= DP distance 2.3060.
#
# Instance 928: Processing 66 edges...
# Instance 928: Custom distance 2.4231 <= DP distance 2.4231.
#
# Instance 929: Processing 66 edges...
# Instance 929: Custom distance 2.3695 <= DP distance 2.3695.
#
# Instance 930: Processing 66 edges...
# Instance 930: Custom distance 2.1540 <= DP distance 2.1540.
#
# Instance 931: Processing 66 edges...
# Instance 931: Custom distance 2.3593 <= DP distance 2.3593.
#
# Instance 932: Processing 66 edges...
# Instance 932: Custom distance 2.0464 <= DP distance 2.0464.
#
# Instance 933: Processing 66 edges...
# Instance 933: Custom distance 1.4992 <= DP distance 1.4992.
#
# Instance 934: Processing 66 edges...
# Instance 934: Custom distance 2.7523 <= DP distance 2.7523.
#
# Instance 935: Processing 66 edges...
# Instance 935: Custom distance 2.3707 <= DP distance 2.3707.
#
# Instance 936: Processing 66 edges...
# Instance 936: Custom distance 2.2368 <= DP distance 2.2368.
#
# Instance 937: Processing 66 edges...
# Instance 937: Custom distance 2.3971 <= DP distance 2.3971.
#
# Instance 938: Processing 66 edges...
# Instance 938: Custom distance 2.6087 <= DP distance 2.6087.
#
# Instance 939: Processing 66 edges...
# Instance 939: Custom distance 2.1348 <= DP distance 2.1348.
#
# Instance 940: Processing 66 edges...
# Instance 940: Custom distance 2.3734 <= DP distance 2.3734.
#
# Instance 941: Processing 66 edges...
# Instance 941: Custom distance 3.1807 <= DP distance 3.1807.
#
# Instance 942: Processing 66 edges...
# Instance 942: Custom distance 2.3102 <= DP distance 2.3102.
#
# Instance 943: Processing 66 edges...
# Instance 943: Custom distance 2.1147 <= DP distance 2.1147.
#
# Instance 944: Processing 66 edges...
# Instance 944: Custom distance 2.6232 <= DP distance 2.6232.
#
# Instance 945: Processing 66 edges...
# Instance 945: Custom distance 2.2919 <= DP distance 2.2919.
#
# Instance 946: Processing 66 edges...
# Instance 946: Custom distance 2.6048 <= DP distance 2.6048.
#
# Instance 947: Processing 66 edges...
# Instance 947: Custom distance 2.4975 <= DP distance 2.4975.
#
# Instance 948: Processing 66 edges...
# Instance 948: Custom distance 2.8530 <= DP distance 2.8530.
#
# Instance 949: Processing 66 edges...
# Instance 949: Custom distance 2.4709 <= DP distance 2.4709.
#
# Instance 950: Processing 66 edges...
# Instance 950: Custom distance 2.7480 <= DP distance 2.7480.
#
# Instance 951: Processing 66 edges...
# Instance 951: Custom distance 2.2646 <= DP distance 2.2646.
#
# Instance 952: Processing 66 edges...
# Instance 952: Custom distance 2.3394 <= DP distance 2.3394.
#
# Instance 953: Processing 66 edges...
# Instance 953: Custom distance 1.4971 <= DP distance 1.4971.
#
# Instance 954: Processing 66 edges...
# Instance 954: Custom distance 2.3589 <= DP distance 2.3589.
#
# Instance 955: Processing 66 edges...
# Instance 955: Custom distance 2.6663 <= DP distance 2.6663.
#
# Instance 956: Processing 66 edges...
# Instance 956: Custom distance 2.4301 <= DP distance 2.4301.
#
# Instance 957: Processing 66 edges...
# Instance 957: Custom distance 2.4299 <= DP distance 2.4299.
#
# Instance 958: Processing 66 edges...
# Instance 958: Custom distance 2.6581 <= DP distance 2.6581.
#
# Instance 959: Processing 66 edges...
# Instance 959: Custom distance 2.8670 <= DP distance 2.8670.
#
# Instance 960: Processing 66 edges...
# Instance 960: Custom distance 2.5259 <= DP distance 2.5259.
#
# Instance 961: Processing 66 edges...
# Instance 961: Custom distance 2.1975 <= DP distance 2.1975.
#
# Instance 962: Processing 66 edges...
# Instance 962: Custom distance 2.3754 <= DP distance 2.3754.
#
# Instance 963: Processing 66 edges...
# Instance 963: Custom distance 2.5678 <= DP distance 2.5678.
#
# Instance 964: Processing 66 edges...
# Instance 964: Custom distance 2.2934 <= DP distance 2.2934.
#
# Instance 965: Processing 66 edges...
# Instance 965: Custom distance 2.4836 <= DP distance 2.4836.
#
# Instance 966: Processing 66 edges...
# Instance 966: Custom distance 2.5750 <= DP distance 2.5750.
#
# Instance 967: Processing 66 edges...
# Instance 967: Custom distance 2.6631 <= DP distance 2.6631.
#
# Instance 968: Processing 66 edges...
# Instance 968: Custom distance 2.1772 <= DP distance 2.1772.
#
# Instance 969: Processing 66 edges...
# Instance 969: Custom distance 2.4069 <= DP distance 2.4069.
#
# Instance 970: Processing 66 edges...
# Instance 970: Custom distance 2.2369 <= DP distance 2.2369.
#
# Instance 971: Processing 66 edges...
# Instance 971: Custom distance 2.8111 <= DP distance 2.8111.
#
# Instance 972: Processing 66 edges...
# Instance 972: Custom distance 2.5071 <= DP distance 2.5071.
#
# Instance 973: Processing 66 edges...
# Instance 973: Custom distance 2.0106 <= DP distance 2.0106.
#
# Instance 974: Processing 66 edges...
# Instance 974: Custom distance 2.6809 <= DP distance 2.6809.
#
# Instance 975: Processing 66 edges...
# Instance 975: Custom distance 2.2515 <= DP distance 2.2515.
#
# Instance 976: Processing 66 edges...
# Instance 976: Custom distance 2.3569 <= DP distance 2.3569.
#
# Instance 977: Processing 66 edges...
# Instance 977: Custom distance 2.2650 <= DP distance 2.2650.
#
# Instance 978: Processing 66 edges...
# Instance 978: Custom distance 2.3027 <= DP distance 2.3027.
#
# Instance 979: Processing 66 edges...
# Instance 979: Custom distance 2.7086 <= DP distance 2.7086.
#
# Instance 980: Processing 66 edges...
# Instance 980: Custom distance 2.1777 <= DP distance 2.1777.
#
# Instance 981: Processing 66 edges...
# Instance 981: Custom distance 2.5695 <= DP distance 2.5695.
#
# Instance 982: Processing 66 edges...
# Instance 982: Custom distance 2.6901 <= DP distance 2.6901.
#
# Instance 983: Processing 66 edges...
# Instance 983: Custom distance 2.4370 <= DP distance 2.4370.
#
# Instance 984: Processing 66 edges...
# Instance 984: Custom distance 2.1907 <= DP distance 2.1907.
#
# Instance 985: Processing 66 edges...
# Instance 985: Custom distance 2.8070 <= DP distance 2.8070.
#
# Instance 986: Processing 66 edges...
# Instance 986: Custom distance 2.9630 <= DP distance 2.9630.
#
# Instance 987: Processing 66 edges...
# Instance 987: Custom distance 2.5887 <= DP distance 2.5887.
#
# Instance 988: Processing 66 edges...
# Instance 988: Custom distance 2.6896 <= DP distance 2.6896.
#
# Instance 989: Processing 66 edges...
# Instance 989: Custom distance 2.5375 <= DP distance 2.5375.
#
# Instance 990: Processing 66 edges...
# Instance 990: Custom distance 2.6008 <= DP distance 2.6008.
#
# Instance 991: Processing 66 edges...
# Instance 991: Custom distance 2.0450 <= DP distance 2.0450.
#
# Instance 992: Processing 66 edges...
# Instance 992: Custom distance 2.7573 <= DP distance 2.7573.
#
# Instance 993: Processing 66 edges...
# Instance 993: Custom distance 2.2320 <= DP distance 2.2320.
#
# Instance 994: Processing 66 edges...
# Instance 994: Custom distance 2.9112 <= DP distance 2.9112.
#
# Instance 995: Processing 66 edges...
# Instance 995: Custom distance 2.9564 <= DP distance 2.9564.
#
# Instance 996: Processing 66 edges...
# Instance 996: Custom distance 2.5100 <= DP distance 2.5100.
#
# Instance 997: Processing 66 edges...
# Instance 997: Custom distance 2.2607 <= DP distance 2.2607.
#
# Instance 998: Processing 66 edges...
# Instance 998: Custom distance 1.9549 <= DP distance 1.9549.
#
# Instance 999: Processing 66 edges...
# Instance 999: Custom distance 2.3833 <= DP distance 2.3833.
#
# Instance 1000: Processing 66 edges...
# Instance 1000: Custom distance 2.7552 <= DP distance 2.7552.
#
# Benchmarking Summary:
# Total Instances Run: 1000 out of 1000
# Custom Algorithm - Average Distance: 2.4610
# DP Solution       - Average Distance: 2.4610
# Average Improvement by Custom Algorithm: 0.00%

# %%
benchmark_hamiltonian_path(n=16, instances=1000, seed=42)
# Out:
# Starting Benchmark: 1000 instances with n=16 points each.
#
# Instance 1: Processing 120 edges...
# Instance 1: Custom distance 3.17598660 ≈ DP distance 3.17598660.
#
# Instance 2: Processing 120 edges...
# Instance 2: Custom distance 3.10043929 ≈ DP distance 3.10043929.
#
# Instance 3: Processing 120 edges...
# Instance 3: Custom distance 2.75932106 ≈ DP distance 2.75932106.
#
# Instance 4: Processing 120 edges...
# Instance 4: Custom distance 2.72130219 ≈ DP distance 2.72130219.
#
# Instance 5: Processing 120 edges...
# Instance 5: Custom distance 3.15638882 ≈ DP distance 3.15638882.
#
# Instance 6: Processing 120 edges...
# Instance 6: Custom distance 2.47400444 ≈ DP distance 2.47400444.
#
# Instance 7: Processing 120 edges...
# Instance 7: Custom distance 3.02951055 ≈ DP distance 3.02951055.
#
# Instance 8: Processing 120 edges...
# Instance 8: Custom distance 2.81406469 ≈ DP distance 2.81406469.
#
# Instance 9: Processing 120 edges...
# Instance 9: Custom distance 2.54917650 ≈ DP distance 2.54917650.
#
# Instance 10: Processing 120 edges...
# Instance 10: Custom distance 2.83288616 ≈ DP distance 2.83288616.
#
# Instance 11: Processing 120 edges...
# Instance 11: Custom distance 2.24773901 ≈ DP distance 2.24773901.
#
# Instance 12: Processing 120 edges...
# Instance 12: Custom distance 3.15352374 ≈ DP distance 3.15352374.
#
# Instance 13: Processing 120 edges...
# Instance 13: Custom distance 2.98510354 ≈ DP distance 2.98510354.
#
# Instance 14: Processing 120 edges...
# Instance 14: Custom distance 3.20285271 ≈ DP distance 3.20285271.
#
# Instance 15: Processing 120 edges...
# Instance 15: Custom distance 3.52674810 ≈ DP distance 3.52674810.
#
# Instance 16: Processing 120 edges...
# Instance 16: Custom distance 3.05905198 ≈ DP distance 3.05905198.
#
# Instance 17: Processing 120 edges...
# Instance 17: Custom distance 2.60427926 ≈ DP distance 2.60427926.
#
# Instance 18: Processing 120 edges...
# Instance 18: Custom distance 3.03168292 ≈ DP distance 3.03168292.
#
# Instance 19: Processing 120 edges...
# Instance 19: Custom distance 2.94734400 ≈ DP distance 2.94734400.
#
# Instance 20: Processing 120 edges...
# Instance 20: Custom distance 2.98038947 ≈ DP distance 2.98038947.
#
# Instance 21: Processing 120 edges...
# Instance 21: Custom distance 2.99850261 ≈ DP distance 2.99850261.
#
# Instance 22: Processing 120 edges...
# Instance 22: Custom distance 2.58947862 ≈ DP distance 2.58947862.
#
# Instance 23: Processing 120 edges...
# Instance 23: Custom distance 2.70122574 ≈ DP distance 2.70122574.
#
# Instance 24: Processing 120 edges...
# Instance 24: Custom distance 2.45515876 ≈ DP distance 2.45515876.
#
# Instance 25: Processing 120 edges...
# Instance 25: Custom distance 3.04830856 ≈ DP distance 3.04830856.
#
# Instance 26: Processing 120 edges...
# Instance 26: Custom distance 2.77750117 ≈ DP distance 2.77750117.
#
# Instance 27: Processing 120 edges...
# Instance 27: Custom distance 2.68302565 ≈ DP distance 2.68302565.
#
# Instance 28: Processing 120 edges...
# Instance 28: Custom distance 3.23591900 ≈ DP distance 3.23591900.
#
# Instance 29: Processing 120 edges...
# Instance 29: Custom distance 2.88055508 ≈ DP distance 2.88055508.
#
# Instance 30: Processing 120 edges...
# Instance 30: Custom distance 2.66166493 ≈ DP distance 2.66166493.
#
# Instance 31: Processing 120 edges...
# Instance 31: Custom distance 3.01577359 ≈ DP distance 3.01577359.
#
# Instance 32: Processing 120 edges...
# Instance 32: Custom distance 3.06178743 ≈ DP distance 3.06178743.
#
# Instance 33: Processing 120 edges...
# Instance 33: Custom distance 2.95590650 ≈ DP distance 2.95590650.
#
# Instance 34: Processing 120 edges...
# Instance 34: Custom distance 2.74304942 ≈ DP distance 2.74304942.
#
# Instance 35: Processing 120 edges...
# Instance 35: Custom distance 2.62509876 ≈ DP distance 2.62509876.
#
# Instance 36: Processing 120 edges...
# Instance 36: Custom distance 3.03374034 ≈ DP distance 3.03374034.
#
# Instance 37: Processing 120 edges...
# Instance 37: Custom distance 2.81952930 ≈ DP distance 2.81952930.
#
# Instance 38: Processing 120 edges...
# Instance 38: Custom distance 3.07418103 ≈ DP distance 3.07418103.
#
# Instance 39: Processing 120 edges...
# Instance 39: Custom distance 3.03825228 ≈ DP distance 3.03825228.
#
# Instance 40: Processing 120 edges...
# Instance 40: Custom distance 2.79529748 ≈ DP distance 2.79529748.
#
# Instance 41: Processing 120 edges...
# Instance 41: Custom distance 2.33156962 ≈ DP distance 2.33156962.
#
# Instance 42: Processing 120 edges...
# Instance 42: Custom distance 3.11000384 ≈ DP distance 3.11000384.
#
# Instance 43: Processing 120 edges...
# Instance 43: Custom distance 2.42336965 ≈ DP distance 2.42336965.
#
# Instance 44: Processing 120 edges...
# Instance 44: Custom distance 2.66671432 ≈ DP distance 2.66671432.
#
# Instance 45: Processing 120 edges...
# Instance 45: Custom distance 3.12698397 ≈ DP distance 3.12698397.
#
# Instance 46: Processing 120 edges...
# Instance 46: Custom distance 2.86295549 ≈ DP distance 2.86295549.
#
# Instance 47: Processing 120 edges...
# Instance 47: Custom distance 2.68123418 ≈ DP distance 2.68123418.
#
# Instance 48: Processing 120 edges...
# Instance 48: Custom distance 3.38298168 ≈ DP distance 3.38298168.
#
# Instance 49: Processing 120 edges...
# Instance 49: Custom distance 3.30825125 ≈ DP distance 3.30825125.
#
# Instance 50: Processing 120 edges...
# Instance 50: Custom distance 2.36622583 ≈ DP distance 2.36622583.
#
# Instance 51: Processing 120 edges...
# Instance 51: Custom distance 3.06142142 ≈ DP distance 3.06142142.
#
# Instance 52: Processing 120 edges...
# Instance 52: Custom distance 2.71678199 ≈ DP distance 2.71678199.
#
# Instance 53: Processing 120 edges...
# Instance 53: Custom distance 2.48220063 ≈ DP distance 2.48220063.
#
# Instance 54: Processing 120 edges...
# Instance 54: Custom distance 2.97904222 ≈ DP distance 2.97904222.
#
# Instance 55: Processing 120 edges...
# Instance 55: Custom distance 2.76914905 ≈ DP distance 2.76914905.
#
# Instance 56: Processing 120 edges...
# Instance 56: Custom distance 3.01903250 ≈ DP distance 3.01903250.
#
# Instance 57: Processing 120 edges...
# Instance 57: Custom distance 3.12546931 ≈ DP distance 3.12546931.
#
# Instance 58: Processing 120 edges...
# Instance 58: Custom distance 2.94642549 ≈ DP distance 2.94642549.
#
# Instance 59: Processing 120 edges...
# Instance 59: Custom distance 2.96591145 ≈ DP distance 2.96591145.
#
# Instance 60: Processing 120 edges...
# Instance 60: Custom distance 2.45707522 ≈ DP distance 2.45707522.
#
# Instance 61: Processing 120 edges...
# Instance 61: Custom distance 2.77332808 ≈ DP distance 2.77332808.
#
# Instance 62: Processing 120 edges...
# Instance 62: Custom distance 2.69359402 ≈ DP distance 2.69359402.
#
# Instance 63: Processing 120 edges...
# Instance 63: Custom distance 2.86402901 ≈ DP distance 2.86402901.
#
# Instance 64: Processing 120 edges...
# Instance 64: Custom distance 2.83269909 ≈ DP distance 2.83269909.
#
# Instance 65: Processing 120 edges...
# Instance 65: Custom distance 2.97415374 ≈ DP distance 2.97415374.
#
# Instance 66: Processing 120 edges...
# Instance 66: Custom distance 2.79875057 ≈ DP distance 2.79875057.
#
# Instance 67: Processing 120 edges...
# Instance 67: Custom distance 3.32315767 ≈ DP distance 3.32315767.
#
# Instance 68: Processing 120 edges...
# Instance 68: Custom distance 2.87479919 ≈ DP distance 2.87479919.
#
# Instance 69: Processing 120 edges...
# Instance 69: Custom distance 2.92099685 ≈ DP distance 2.92099685.
#
# Instance 70: Processing 120 edges...
# Instance 70: Custom distance 3.28150780 ≈ DP distance 3.28150780.
#
# Instance 71: Processing 120 edges...
# Instance 71: Custom distance 2.90071738 ≈ DP distance 2.90071738.
#
# Instance 72: Processing 120 edges...
# Instance 72: Custom distance 2.47114902 ≈ DP distance 2.47114902.
#
# Instance 73: Processing 120 edges...
# Instance 73: Custom distance 3.16232293 ≈ DP distance 3.16232293.
#
# Instance 74: Processing 120 edges...
# Instance 74: Custom distance 3.09318883 ≈ DP distance 3.09318883.
#
# Instance 75: Processing 120 edges...
# Instance 75: Custom distance 3.12424461 ≈ DP distance 3.12424461.
#
# Instance 76: Processing 120 edges...
# Instance 76: Custom distance 3.54255289 ≈ DP distance 3.54255289.
#
# Instance 77: Processing 120 edges...
# Instance 77: Custom distance 2.89776390 ≈ DP distance 2.89776390.
#
# Instance 78: Processing 120 edges...
# Instance 78: Custom distance 2.71491626 ≈ DP distance 2.71491626.
#
# Instance 79: Processing 120 edges...
# Instance 79: Custom distance 2.72931980 ≈ DP distance 2.72931980.
#
# Instance 80: Processing 120 edges...
# Instance 80: Custom distance 2.69531816 ≈ DP distance 2.69531816.
#
# Instance 81: Processing 120 edges...
# Instance 81: Custom distance 2.67795132 ≈ DP distance 2.67795132.
#
# Instance 82: Processing 120 edges...
# Instance 82: Custom distance 2.66092969 ≈ DP distance 2.66092969.
#
# Instance 83: Processing 120 edges...
# Instance 83: Custom distance 3.10857063 ≈ DP distance 3.10857063.
#
# Instance 84: Processing 120 edges...
# Instance 84: Custom distance 2.61524887 ≈ DP distance 2.61524887.
#
# Instance 85: Processing 120 edges...
# Instance 85: Custom distance 3.05938135 ≈ DP distance 3.05938135.
#
# Instance 86: Processing 120 edges...
# Instance 86: Custom distance 2.83788870 ≈ DP distance 2.83788870.
#
# Instance 87: Processing 120 edges...
# Instance 87: Custom distance 2.64399065 ≈ DP distance 2.64399065.
#
# Instance 88: Processing 120 edges...
# Instance 88: Custom distance 3.21999534 ≈ DP distance 3.21999534.
#
# Instance 89: Processing 120 edges...
# Instance 89: Custom distance 2.62536935 ≈ DP distance 2.62536935.
#
# Instance 90: Processing 120 edges...
# Instance 90: Custom distance 2.60009264 ≈ DP distance 2.60009264.
#
# Instance 91: Processing 120 edges...
# Instance 91: Custom distance 2.30685054 ≈ DP distance 2.30685054.
#
# Instance 92: Processing 120 edges...
# Instance 92: Custom distance 2.60326099 ≈ DP distance 2.60326099.
#
# Instance 93: Processing 120 edges...
# Instance 93: Custom distance 3.12248956 ≈ DP distance 3.12248956.
#
# Instance 94: Processing 120 edges...
# Instance 94: Custom distance 2.60855915 ≈ DP distance 2.60855915.
#
# Instance 95: Processing 120 edges...
# Instance 95: Custom distance 2.76858276 ≈ DP distance 2.76858276.
#
# Instance 96: Processing 120 edges...
# Instance 96: Custom distance 3.34099630 ≈ DP distance 3.34099630.
#
# Instance 97: Processing 120 edges...
# Instance 97: Custom distance 3.39624199 ≈ DP distance 3.39624199.
#
# Instance 98: Processing 120 edges...
# Instance 98: Custom distance 2.92536338 ≈ DP distance 2.92536338.
#
# Instance 99: Processing 120 edges...
# Instance 99: Custom distance 2.98365807 ≈ DP distance 2.98365807.
#
# Instance 100: Processing 120 edges...
# Instance 100: Custom distance 2.82318606 ≈ DP distance 2.82318606.
#
# Instance 101: Processing 120 edges...
# Instance 101: Custom distance 3.26284794 ≈ DP distance 3.26284794.
#
# Instance 102: Processing 120 edges...
# Instance 102: Custom distance 3.34788936 ≈ DP distance 3.34788936.
#
# Instance 103: Processing 120 edges...
# Instance 103: Custom distance 2.94426545 ≈ DP distance 2.94426545.
#
# Instance 104: Processing 120 edges...
# Instance 104: Custom distance 3.47710344 ≈ DP distance 3.47710344.
#
# Instance 105: Processing 120 edges...
# Instance 105: Custom distance 3.70251540 ≈ DP distance 3.70251540.
#
# Instance 106: Processing 120 edges...
# Instance 106: Custom distance 3.25954557 ≈ DP distance 3.25954557.
#
# Instance 107: Processing 120 edges...
# Instance 107: Custom distance 2.82535435 ≈ DP distance 2.82535435.
#
# Instance 108: Processing 120 edges...
# Instance 108: Custom distance 2.81390595 ≈ DP distance 2.81390595.
#
# Instance 109: Processing 120 edges...
# Instance 109: Custom distance 3.03093449 ≈ DP distance 3.03093449.
#
# Instance 110: Processing 120 edges...
# Instance 110: Custom distance 3.02077451 ≈ DP distance 3.02077451.
#
# Instance 111: Processing 120 edges...
# Instance 111: Custom distance 2.98090710 ≈ DP distance 2.98090710.
#
# Instance 112: Processing 120 edges...
# Instance 112: Custom distance 2.90544841 ≈ DP distance 2.90544841.
#
# Instance 113: Processing 120 edges...
# Instance 113: Custom distance 2.75344886 ≈ DP distance 2.75344886.
#
# Instance 114: Processing 120 edges...
# Instance 114: Custom distance 3.00622086 ≈ DP distance 3.00622086.
#
# Instance 115: Processing 120 edges...
# Instance 115: Custom distance 3.01247479 ≈ DP distance 3.01247479.
#
# Instance 116: Processing 120 edges...
# Instance 116: Custom distance 2.96428704 ≈ DP distance 2.96428704.
#
# Instance 117: Processing 120 edges...
# Instance 117: Custom distance 3.39024492 ≈ DP distance 3.39024492.
#
# Instance 118: Processing 120 edges...
# Instance 118: Custom distance 3.16824137 ≈ DP distance 3.16824137.
#
# Instance 119: Processing 120 edges...
# Instance 119: Custom distance 2.26386158 ≈ DP distance 2.26386158.
#
# Instance 120: Processing 120 edges...
# Instance 120: Custom distance 2.84355767 ≈ DP distance 2.84355767.
#
# Instance 121: Processing 120 edges...
# Instance 121: Custom distance 2.49776250 ≈ DP distance 2.49776250.
#
# Instance 122: Processing 120 edges...
# Instance 122: Custom distance 2.62602377 ≈ DP distance 2.62602377.
#
# Instance 123: Processing 120 edges...
# Instance 123: Custom distance 3.14725490 ≈ DP distance 3.14725490.
#
# Instance 124: Processing 120 edges...
# Instance 124: Custom distance 2.65273977 ≈ DP distance 2.65273977.
#
# Instance 125: Processing 120 edges...
# Instance 125: Custom distance 2.82840590 ≈ DP distance 2.82840590.
#
# Instance 126: Processing 120 edges...
# Instance 126: Custom distance 2.63943919 ≈ DP distance 2.63943919.
#
# Instance 127: Processing 120 edges...
# Instance 127: Custom distance 3.08132619 ≈ DP distance 3.08132619.
#
# Instance 128: Processing 120 edges...
# Instance 128: Custom distance 3.03401142 ≈ DP distance 3.03401142.
#
# Instance 129: Processing 120 edges...
# Instance 129: Custom distance 2.61617766 ≈ DP distance 2.61617766.
#
# Instance 130: Processing 120 edges...
# Instance 130: Custom distance 2.68164859 ≈ DP distance 2.68164859.
#
# Instance 131: Processing 120 edges...
# Instance 131: Custom distance 3.10065594 ≈ DP distance 3.10065594.
#
# Instance 132: Processing 120 edges...
# Instance 132: Custom distance 3.11147817 ≈ DP distance 3.11147817.
#
# Instance 133: Processing 120 edges...
# Instance 133: Custom distance 3.76352563 ≈ DP distance 3.76352563.
#
# Instance 134: Processing 120 edges...
# Instance 134: Custom distance 2.71488651 ≈ DP distance 2.71488651.
#
# Instance 135: Processing 120 edges...
# Instance 135: Custom distance 2.51774399 ≈ DP distance 2.51774399.
#
# Instance 136: Processing 120 edges...
# Instance 136: Custom distance 3.13054453 ≈ DP distance 3.13054453.
#
# Instance 137: Processing 120 edges...
# Instance 137: Custom distance 3.01858503 ≈ DP distance 3.01858503.
#
# Instance 138: Processing 120 edges...
# Instance 138: Custom distance 2.57955084 ≈ DP distance 2.57955084.
#
# Instance 139: Processing 120 edges...
# Instance 139: Custom distance 3.33626981 ≈ DP distance 3.33626981.
#
# Instance 140: Processing 120 edges...
# Instance 140: Custom distance 3.08362857 ≈ DP distance 3.08362857.
#
# Instance 141: Processing 120 edges...
# Instance 141: Custom distance 2.82407112 ≈ DP distance 2.82407112.
#
# Instance 142: Processing 120 edges...
# Instance 142: Custom distance 3.00242939 ≈ DP distance 3.00242939.
#
# Instance 143: Processing 120 edges...
# Instance 143: Custom distance 3.19699166 ≈ DP distance 3.19699166.
#
# Instance 144: Processing 120 edges...
# Instance 144: Custom distance 2.76987308 ≈ DP distance 2.76987308.
#
# Instance 145: Processing 120 edges...
# Instance 145: Custom distance 2.80262618 ≈ DP distance 2.80262618.
#
# Instance 146: Processing 120 edges...
# Instance 146: Custom distance 2.95843366 ≈ DP distance 2.95843366.
#
# Instance 147: Processing 120 edges...
# Instance 147: Custom distance 2.70241785 ≈ DP distance 2.70241785.
#
# Instance 148: Processing 120 edges...
# Instance 148: Custom distance 2.81199266 ≈ DP distance 2.81199266.
#
# Instance 149: Processing 120 edges...
# Instance 149: Custom distance 2.80992916 ≈ DP distance 2.80992916.
#
# Instance 150: Processing 120 edges...
# Instance 150: Custom distance 2.59275608 ≈ DP distance 2.59275608.
#
# Instance 151: Processing 120 edges...
# Instance 151: Custom distance 2.75304173 ≈ DP distance 2.75304173.
#
# Instance 152: Processing 120 edges...
# Instance 152: Custom distance 3.17533216 ≈ DP distance 3.17533216.
#
# Instance 153: Processing 120 edges...
# Instance 153: Custom distance 3.14396403 ≈ DP distance 3.14396403.
#
# Instance 154: Processing 120 edges...
# Instance 154: Custom distance 2.88354745 ≈ DP distance 2.88354745.
#
# Instance 155: Processing 120 edges...
# Instance 155: Custom distance 3.04286562 ≈ DP distance 3.04286562.
#
# Instance 156: Processing 120 edges...
# Instance 156: Custom distance 2.57179636 ≈ DP distance 2.57179636.
#
# Instance 157: Processing 120 edges...
# Instance 157: Custom distance 3.00437863 ≈ DP distance 3.00437863.
#
# Instance 158: Processing 120 edges...
# Instance 158: Custom distance 2.81621111 ≈ DP distance 2.81621111.
#
# Instance 159: Processing 120 edges...
# Instance 159: Custom distance 2.92702375 ≈ DP distance 2.92702375.
#
# Instance 160: Processing 120 edges...
# Instance 160: Custom distance 2.64975510 ≈ DP distance 2.64975510.
#
# Instance 161: Processing 120 edges...
# Instance 161: Custom distance 2.94699795 ≈ DP distance 2.94699795.
#
# Instance 162: Processing 120 edges...
# Instance 162: Custom distance 2.99988524 ≈ DP distance 2.99988524.
#
# Instance 163: Processing 120 edges...
# Instance 163: Custom distance 2.84595159 ≈ DP distance 2.84595159.
#
# Instance 164: Processing 120 edges...
# Instance 164: Custom distance 2.39260881 ≈ DP distance 2.39260881.
#
# Instance 165: Processing 120 edges...
# Instance 165: Custom distance 3.15192754 ≈ DP distance 3.15192754.
#
# Instance 166: Processing 120 edges...
# Instance 166: Custom distance 2.97652244 ≈ DP distance 2.97652244.
#
# Instance 167: Processing 120 edges...
# Instance 167: Custom distance 2.85940102 ≈ DP distance 2.85940102.
#
# Instance 168: Processing 120 edges...
# Instance 168: Custom distance 3.11912287 ≈ DP distance 3.11912287.
#
# Instance 169: Processing 120 edges...
# Instance 169: Custom distance 2.73048638 ≈ DP distance 2.73048638.
#
# Instance 170: Processing 120 edges...
# Instance 170: Custom distance 3.34652456 ≈ DP distance 3.34652456.
#
# Instance 171: Processing 120 edges...
# Instance 171: Custom distance 2.86400645 ≈ DP distance 2.86400645.
#
# Instance 172: Processing 120 edges...
# Instance 172: Custom distance 2.72010462 ≈ DP distance 2.72010462.
#
# Instance 173: Processing 120 edges...
# Instance 173: Custom distance 2.79988327 ≈ DP distance 2.79988327.
#
# Instance 174: Processing 120 edges...
# Instance 174: Custom distance 3.03341358 ≈ DP distance 3.03341358.
#
# Instance 175: Processing 120 edges...
# Instance 175: Custom distance 2.91856898 ≈ DP distance 2.91856898.
#
# Instance 176: Processing 120 edges...
# Instance 176: Custom distance 3.14698296 ≈ DP distance 3.14698296.
#
# Instance 177: Processing 120 edges...
# Instance 177: Custom distance 2.89445172 ≈ DP distance 2.89445172.
#
# Instance 178: Processing 120 edges...
# Instance 178: Custom distance 2.69085461 ≈ DP distance 2.69085461.
#
# Instance 179: Processing 120 edges...
# Instance 179: Custom distance 3.34015993 ≈ DP distance 3.34015993.
#
# Instance 180: Processing 120 edges...
# Instance 180: Custom distance 3.01407990 ≈ DP distance 3.01407990.
#
# Instance 181: Processing 120 edges...
# Instance 181: Custom distance 3.34848841 ≈ DP distance 3.34848841.
#
# Instance 182: Processing 120 edges...
# Instance 182: Custom distance 2.29385308 ≈ DP distance 2.29385308.
#
# Instance 183: Processing 120 edges...
# Instance 183: Custom distance 2.89659885 ≈ DP distance 2.89659885.
#
# Instance 184: Processing 120 edges...
# Instance 184: Custom distance 2.95638860 ≈ DP distance 2.95638860.
#
# Instance 185: Processing 120 edges...
# Instance 185: Custom distance 3.09073154 ≈ DP distance 3.09073154.
#
# Instance 186: Processing 120 edges...
# Instance 186: Custom distance 2.91181088 ≈ DP distance 2.91181088.
#
# Instance 187: Processing 120 edges...
# Instance 187: Custom distance 2.82109418 ≈ DP distance 2.82109418.
#
# Instance 188: Processing 120 edges...
# Instance 188: Custom distance 2.50974872 ≈ DP distance 2.50974872.
#
# Instance 189: Processing 120 edges...
# Instance 189: Custom distance 3.20201156 ≈ DP distance 3.20201156.
#
# Instance 190: Processing 120 edges...
# Instance 190: Custom distance 2.53498824 ≈ DP distance 2.53498824.
#
# Instance 191: Processing 120 edges...
# Instance 191: Custom distance 3.03690125 ≈ DP distance 3.03690125.
#
# Instance 192: Processing 120 edges...
# Instance 192: Custom distance 3.10815471 ≈ DP distance 3.10815471.
#
# Instance 193: Processing 120 edges...
# Instance 193: Custom distance 3.00943582 ≈ DP distance 3.00943582.
#
# Instance 194: Processing 120 edges...
# Instance 194: Custom distance 2.91156092 ≈ DP distance 2.91156092.
#
# Instance 195: Processing 120 edges...
# Instance 195: Custom distance 3.02295841 ≈ DP distance 3.02295841.
#
# Instance 196: Processing 120 edges...
# Instance 196: Custom distance 3.11592285 ≈ DP distance 3.11592285.
#
# Instance 197: Processing 120 edges...
# Instance 197: Custom distance 3.05163451 ≈ DP distance 3.05163451.
#
# Instance 198: Processing 120 edges...
# Instance 198: Custom distance 2.89036555 ≈ DP distance 2.89036555.
#
# Instance 199: Processing 120 edges...
# Instance 199: Custom distance 2.79324934 ≈ DP distance 2.79324934.
#
# Instance 200: Processing 120 edges...
# Instance 200: Custom distance 2.53081594 ≈ DP distance 2.53081594.
#
# Instance 201: Processing 120 edges...
# Instance 201: Custom distance 2.32286557 ≈ DP distance 2.32286557.
#
# Instance 202: Processing 120 edges...
# Instance 202: Custom distance 2.83780416 ≈ DP distance 2.83780416.
#
# Instance 203: Processing 120 edges...
# Instance 203: Custom distance 3.22728435 ≈ DP distance 3.22728435.
#
# Instance 204: Processing 120 edges...
# Instance 204: Custom distance 2.71450230 ≈ DP distance 2.71450230.
#
# Instance 205: Processing 120 edges...
# Instance 205: Custom distance 2.79247766 ≈ DP distance 2.79247766.
#
# Instance 206: Processing 120 edges...
# Instance 206: Custom distance 2.67266987 ≈ DP distance 2.67266987.
#
# Instance 207: Processing 120 edges...
# Instance 207: Custom distance 2.86875640 ≈ DP distance 2.86875640.
#
# Instance 208: Processing 120 edges...
# Instance 208: Custom distance 2.68550934 ≈ DP distance 2.68550934.
#
# Instance 209: Processing 120 edges...
# Instance 209: Custom distance 3.41681854 ≈ DP distance 3.41681854.
#
# Instance 210: Processing 120 edges...
# Instance 210: Custom distance 3.53071333 ≈ DP distance 3.53071333.
#
# Instance 211: Processing 120 edges...
# Instance 211: Custom distance 3.01294101 ≈ DP distance 3.01294101.
#
# Instance 212: Processing 120 edges...
# Instance 212: Custom distance 2.92328845 ≈ DP distance 2.92328845.
#
# Instance 213: Processing 120 edges...
# Instance 213: Custom distance 2.71051278 ≈ DP distance 2.71051278.
#
# Instance 214: Processing 120 edges...
# Instance 214: Custom distance 2.91164816 ≈ DP distance 2.91164816.
#
# Instance 215: Processing 120 edges...
# Instance 215: Custom distance 3.04772072 ≈ DP distance 3.04772072.
#
# Instance 216: Processing 120 edges...
# Instance 216: Custom distance 2.81353790 ≈ DP distance 2.81353790.
#
# Instance 217: Processing 120 edges...
# Instance 217: Custom distance 2.77654003 ≈ DP distance 2.77654003.
#
# Instance 218: Processing 120 edges...
# Instance 218: Custom distance 2.90751931 ≈ DP distance 2.90751931.
#
# Instance 219: Processing 120 edges...
# Instance 219: Custom distance 2.73588006 ≈ DP distance 2.73588006.
#
# Instance 220: Processing 120 edges...
# Instance 220: Custom distance 3.13190715 ≈ DP distance 3.13190715.
#
# Instance 221: Processing 120 edges...
# Instance 221: Custom distance 3.10068907 ≈ DP distance 3.10068907.
#
# Instance 222: Processing 120 edges...
# Instance 222: Custom distance 2.99063000 ≈ DP distance 2.99063000.
#
# Instance 223: Processing 120 edges...
# Instance 223: Custom distance 3.28819164 ≈ DP distance 3.28819164.
#
# Instance 224: Processing 120 edges...
# Instance 224: Custom distance 3.17580888 ≈ DP distance 3.17580888.
#
# Instance 225: Processing 120 edges...
# Instance 225: Custom distance 3.10851196 ≈ DP distance 3.10851196.
#
# Instance 226: Processing 120 edges...
# Instance 226: Custom distance 3.49212855 ≈ DP distance 3.49212855.
#
# Instance 227: Processing 120 edges...
# Instance 227: Custom distance 2.45868363 ≈ DP distance 2.45868363.
#
# Instance 228: Processing 120 edges...
# Instance 228: Custom distance 3.08902843 ≈ DP distance 3.08902843.
#
# Instance 229: Processing 120 edges...
# Instance 229: Custom distance 2.69153089 ≈ DP distance 2.69153089.
#
# Instance 230: Processing 120 edges...
# Instance 230: Custom distance 3.09245437 ≈ DP distance 3.09245437.
#
# Instance 231: Processing 120 edges...
# Instance 231: Custom distance 3.31203774 ≈ DP distance 3.31203774.
#
# Instance 232: Processing 120 edges...
# Instance 232: Custom distance 2.89358997 ≈ DP distance 2.89358997.
#
# Instance 233: Processing 120 edges...
# Instance 233: Custom distance 3.00542343 ≈ DP distance 3.00542343.
#
# Instance 234: Processing 120 edges...
# Instance 234: Custom distance 3.24273900 ≈ DP distance 3.24273900.
#
# Instance 235: Processing 120 edges...
# Instance 235: Custom distance 2.66305740 ≈ DP distance 2.66305740.
#
# Instance 236: Processing 120 edges...
# Instance 236: Custom distance 2.54460532 ≈ DP distance 2.54460532.
#
# Instance 237: Processing 120 edges...
# Instance 237: Custom distance 3.31549975 ≈ DP distance 3.31549975.
#
# Instance 238: Processing 120 edges...
# Instance 238: Custom distance 2.63787234 ≈ DP distance 2.63787234.
#
# Instance 239: Processing 120 edges...
# Instance 239: Custom distance 2.72659267 ≈ DP distance 2.72659267.
#
# Instance 240: Processing 120 edges...
# Instance 240: Custom distance 2.95994403 ≈ DP distance 2.95994403.
#
# Instance 241: Processing 120 edges...
# Instance 241: Custom distance 2.98577322 ≈ DP distance 2.98577322.
#
# Instance 242: Processing 120 edges...
# Instance 242: Custom distance 3.07608626 ≈ DP distance 3.07608626.
#
# Instance 243: Processing 120 edges...
# Instance 243: Custom distance 2.51147206 ≈ DP distance 2.51147206.
#
# Instance 244: Processing 120 edges...
# Instance 244: Custom distance 3.29877457 ≈ DP distance 3.29877457.
#
# Instance 245: Processing 120 edges...
# Instance 245: Custom distance 3.13008254 ≈ DP distance 3.13008254.
#
# Instance 246: Processing 120 edges...
# Instance 246: Custom distance 3.09297149 ≈ DP distance 3.09297149.
#
# Instance 247: Processing 120 edges...
# Instance 247: Custom distance 3.18215820 ≈ DP distance 3.18215820.
#
# Instance 248: Processing 120 edges...
# Instance 248: Custom distance 3.12343063 ≈ DP distance 3.12343063.
#
# Instance 249: Processing 120 edges...
# Instance 249: Custom distance 2.64262300 ≈ DP distance 2.64262300.
#
# Instance 250: Processing 120 edges...
# Instance 250: Custom distance 3.09105133 ≈ DP distance 3.09105133.
#
# Instance 251: Processing 120 edges...
# Instance 251: Custom distance 2.80362324 ≈ DP distance 2.80362324.
#
# Instance 252: Processing 120 edges...
# Instance 252: Custom distance 2.77404482 ≈ DP distance 2.77404482.
#
# Instance 253: Processing 120 edges...
# Instance 253: Custom distance 2.88344747 ≈ DP distance 2.88344747.
#
# Instance 254: Processing 120 edges...
# Instance 254: Custom distance 3.30690813 ≈ DP distance 3.30690813.
#
# Instance 255: Processing 120 edges...
# Instance 255: Custom distance 3.06617179 ≈ DP distance 3.06617179.
#
# Instance 256: Processing 120 edges...
# Instance 256: Custom distance 3.00072247 ≈ DP distance 3.00072247.
#
# Instance 257: Processing 120 edges...
# Instance 257: Custom distance 2.82932712 ≈ DP distance 2.82932712.
#
# Instance 258: Processing 120 edges...
# Instance 258: Custom distance 2.61846168 ≈ DP distance 2.61846168.
#
# Instance 259: Processing 120 edges...
# Instance 259: Custom distance 3.03680212 ≈ DP distance 3.03680212.
#
# Instance 260: Processing 120 edges...
# Instance 260: Custom distance 2.27001311 ≈ DP distance 2.27001311.
#
# Instance 261: Processing 120 edges...
# Instance 261: Custom distance 2.84489046 ≈ DP distance 2.84489046.
#
# Instance 262: Processing 120 edges...
# Instance 262: Custom distance 2.82303914 ≈ DP distance 2.82303914.
#
# Instance 263: Processing 120 edges...
# Instance 263: Custom distance 3.12465269 ≈ DP distance 3.12465269.
#
# Instance 264: Processing 120 edges...
# Instance 264: Custom distance 3.30051589 ≈ DP distance 3.30051589.
#
# Instance 265: Processing 120 edges...
# Instance 265: Custom distance 2.92731911 ≈ DP distance 2.92731911.
#
# Instance 266: Processing 120 edges...
# Instance 266: Custom distance 2.83577215 ≈ DP distance 2.83577215.
#
# Instance 267: Processing 120 edges...
# Instance 267: Custom distance 2.75721164 ≈ DP distance 2.75721164.
#
# Instance 268: Processing 120 edges...
# Instance 268: Custom distance 3.25721704 ≈ DP distance 3.25721704.
#
# Instance 269: Processing 120 edges...
# Instance 269: Custom distance 2.31082273 ≈ DP distance 2.31082273.
#
# Instance 270: Processing 120 edges...
# Instance 270: Custom distance 2.74525161 ≈ DP distance 2.74525161.
#
# Instance 271: Processing 120 edges...
# Instance 271: Custom distance 2.95593324 ≈ DP distance 2.95593324.
#
# Instance 272: Processing 120 edges...
# Instance 272: Custom distance 2.84556084 ≈ DP distance 2.84556084.
#
# Instance 273: Processing 120 edges...
# Instance 273: Custom distance 3.26790561 ≈ DP distance 3.26790561.
#
# Instance 274: Processing 120 edges...
# Instance 274: Custom distance 3.35681022 ≈ DP distance 3.35681022.
#
# Instance 275: Processing 120 edges...
# Instance 275: Custom distance 2.88475645 ≈ DP distance 2.88475645.
#
# Instance 276: Processing 120 edges...
# Instance 276: Custom distance 2.54489226 ≈ DP distance 2.54489226.
#
# Instance 277: Processing 120 edges...
# Instance 277: Custom distance 3.68214510 ≈ DP distance 3.68214510.
#
# Instance 278: Processing 120 edges...
# Instance 278: Custom distance 3.33154945 ≈ DP distance 3.33154945.
#
# Instance 279: Processing 120 edges...
# Instance 279: Custom distance 2.78667515 ≈ DP distance 2.78667515.
#
# Instance 280: Processing 120 edges...
# Instance 280: Custom distance 2.88550579 ≈ DP distance 2.88550579.
#
# Instance 281: Processing 120 edges...
# Instance 281: Custom distance 3.29104605 ≈ DP distance 3.29104605.
#
# Instance 282: Processing 120 edges...
# Instance 282: Custom distance 3.08280509 ≈ DP distance 3.08280509.
#
# Instance 283: Processing 120 edges...
# Instance 283: Custom distance 2.32849144 ≈ DP distance 2.32849144.
#
# Instance 284: Processing 120 edges...
# Instance 284: Custom distance 2.83716144 ≈ DP distance 2.83716144.
#
# Instance 285: Processing 120 edges...
# Instance 285: Custom distance 2.67958486 ≈ DP distance 2.67958486.
#
# Instance 286: Processing 120 edges...
# Instance 286: Custom distance 2.83470520 ≈ DP distance 2.83470520.
#
# Instance 287: Processing 120 edges...
# Instance 287: Custom distance 2.77490635 ≈ DP distance 2.77490635.
#
# Instance 288: Processing 120 edges...
# Instance 288: Custom distance 3.13480574 ≈ DP distance 3.13480574.
#
# Instance 289: Processing 120 edges...
# Instance 289: Custom distance 2.71413572 ≈ DP distance 2.71413572.
#
# Instance 290: Processing 120 edges...
# Instance 290: Custom distance 2.99138907 ≈ DP distance 2.99138907.
#
# Instance 291: Processing 120 edges...
# Instance 291: Custom distance 3.11158360 ≈ DP distance 3.11158360.
#
# Instance 292: Processing 120 edges...
# Instance 292: Custom distance 2.50870155 ≈ DP distance 2.50870155.
#
# Instance 293: Processing 120 edges...
# Instance 293: Custom distance 2.95342444 ≈ DP distance 2.95342444.
#
# Instance 294: Processing 120 edges...
# Instance 294: Custom distance 2.92818224 ≈ DP distance 2.92818224.
#
# Instance 295: Processing 120 edges...
# Instance 295: Custom distance 2.41447370 ≈ DP distance 2.41447370.
#
# Instance 296: Processing 120 edges...
# Instance 296: Custom distance 2.51455450 ≈ DP distance 2.51455450.
#
# Instance 297: Processing 120 edges...
# Instance 297: Custom distance 2.76895874 ≈ DP distance 2.76895874.
#
# Instance 298: Processing 120 edges...
# Instance 298: Custom distance 3.13473812 ≈ DP distance 3.13473812.
#
# Instance 299: Processing 120 edges...
# Instance 299: Custom distance 2.75134415 ≈ DP distance 2.75134415.
#
# Instance 300: Processing 120 edges...
# Instance 300: Custom distance 2.86554575 ≈ DP distance 2.86554575.
#
# Instance 301: Processing 120 edges...
# Instance 301: Custom distance 2.95951365 ≈ DP distance 2.95951365.
#
# Instance 302: Processing 120 edges...
# Instance 302: Custom distance 2.99676706 ≈ DP distance 2.99676706.
#
# Instance 303: Processing 120 edges...
# Instance 303: Custom distance 2.82500010 ≈ DP distance 2.82500010.
#
# Instance 304: Processing 120 edges...
# Instance 304: Custom distance 2.98485833 ≈ DP distance 2.98485833.
#
# Instance 305: Processing 120 edges...
# Instance 305: Custom distance 2.69776564 ≈ DP distance 2.69776564.
#
# Instance 306: Processing 120 edges...
# Instance 306: Custom distance 2.89593713 ≈ DP distance 2.89593713.
#
# Instance 307: Processing 120 edges...
# Instance 307: Custom distance 2.67363841 ≈ DP distance 2.67363841.
#
# Instance 308: Processing 120 edges...
# Instance 308: Custom distance 3.19453045 ≈ DP distance 3.19453045.
#
# Instance 309: Processing 120 edges...
# Instance 309: Custom distance 3.38342374 ≈ DP distance 3.38342374.
#
# Instance 310: Processing 120 edges...
# Instance 310: Custom distance 2.88188831 ≈ DP distance 2.88188831.
#
# Instance 311: Processing 120 edges...
# Instance 311: Custom distance 2.69428070 ≈ DP distance 2.69428070.
#
# Instance 312: Processing 120 edges...
# Instance 312: Custom distance 2.95323830 ≈ DP distance 2.95323830.
#
# Instance 313: Processing 120 edges...
# Instance 313: Custom distance 2.40172458 ≈ DP distance 2.40172458.
#
# Instance 314: Processing 120 edges...
# Instance 314: Custom distance 2.72288212 ≈ DP distance 2.72288212.
#
# Instance 315: Processing 120 edges...
# Instance 315: Custom distance 3.00937744 ≈ DP distance 3.00937744.
#
# Instance 316: Processing 120 edges...
# Instance 316: Custom distance 3.07664532 ≈ DP distance 3.07664532.
#
# Instance 317: Processing 120 edges...
# Instance 317: Custom distance 2.57935581 ≈ DP distance 2.57935581.
#
# Instance 318: Processing 120 edges...
# Instance 318: Custom distance 2.85822623 ≈ DP distance 2.85822623.
#
# Instance 319: Processing 120 edges...
# Instance 319: Custom distance 2.70133020 ≈ DP distance 2.70133020.
#
# Instance 320: Processing 120 edges...
# Instance 320: Custom distance 3.16668936 ≈ DP distance 3.16668936.
#
# Instance 321: Processing 120 edges...
# Instance 321: Custom distance 3.08468295 ≈ DP distance 3.08468295.
#
# Instance 322: Processing 120 edges...
# Instance 322: Custom distance 3.17057742 ≈ DP distance 3.17057742.
#
# Instance 323: Processing 120 edges...
# Instance 323: Custom distance 2.97439837 ≈ DP distance 2.97439837.
#
# Instance 324: Processing 120 edges...
# Instance 324: Custom distance 3.21590649 ≈ DP distance 3.21590649.
#
# Instance 325: Processing 120 edges...
# Instance 325: Custom distance 2.44501287 ≈ DP distance 2.44501287.
#
# Instance 326: Processing 120 edges...
# Instance 326: Custom distance 3.10490415 ≈ DP distance 3.10490415.
#
# Instance 327: Processing 120 edges...
# Instance 327: Custom distance 3.17815662 ≈ DP distance 3.17815662.
#
# Instance 328: Processing 120 edges...
# Instance 328: Custom distance 2.87725159 ≈ DP distance 2.87725159.
#
# Instance 329: Processing 120 edges...
# Instance 329: Custom distance 3.25791521 ≈ DP distance 3.25791521.
#
# Instance 330: Processing 120 edges...
# Instance 330: Custom distance 3.14200656 ≈ DP distance 3.14200656.
#
# Instance 331: Processing 120 edges...
# Instance 331: Custom distance 2.64722743 ≈ DP distance 2.64722743.
#
# Instance 332: Processing 120 edges...
# Instance 332: Custom distance 2.79183003 ≈ DP distance 2.79183003.
#
# Instance 333: Processing 120 edges...
# Instance 333: Custom distance 3.05760878 ≈ DP distance 3.05760878.
#
# Instance 334: Processing 120 edges...
# Instance 334: Custom distance 2.14407795 ≈ DP distance 2.14407795.
#
# Instance 335: Processing 120 edges...
# Instance 335: Custom distance 2.36781696 ≈ DP distance 2.36781696.
#
# Instance 336: Processing 120 edges...
# Instance 336: Custom distance 3.19495395 ≈ DP distance 3.19495395.
#
# Instance 337: Processing 120 edges...
# Instance 337: Custom distance 2.84065884 ≈ DP distance 2.84065884.
#
# Instance 338: Processing 120 edges...
# Instance 338: Custom distance 2.70817330 ≈ DP distance 2.70817330.
#
# Instance 339: Processing 120 edges...
# Instance 339: Custom distance 3.15046130 ≈ DP distance 3.15046130.
#
# Instance 340: Processing 120 edges...
# Instance 340: Custom distance 2.64211022 ≈ DP distance 2.64211022.
#
# Instance 341: Processing 120 edges...
# Instance 341: Custom distance 3.17421116 ≈ DP distance 3.17421116.
#
# Instance 342: Processing 120 edges...
# Instance 342: Custom distance 2.61103495 ≈ DP distance 2.61103495.
#
# Instance 343: Processing 120 edges...
# Instance 343: Custom distance 2.87458324 ≈ DP distance 2.87458324.
#
# Instance 344: Processing 120 edges...
# Instance 344: Custom distance 2.70837886 ≈ DP distance 2.70837886.
#
# Instance 345: Processing 120 edges...
# Instance 345: Custom distance 2.99787234 ≈ DP distance 2.99787234.
#
# Instance 346: Processing 120 edges...
# Instance 346: Custom distance 3.32201559 ≈ DP distance 3.32201559.
#
# Instance 347: Processing 120 edges...
# Instance 347: Custom distance 2.32885198 ≈ DP distance 2.32885198.
#
# Instance 348: Processing 120 edges...
# Instance 348: Custom distance 3.31732083 ≈ DP distance 3.31732083.
#
# Instance 349: Processing 120 edges...
# Instance 349: Custom distance 2.76190543 ≈ DP distance 2.76190543.
#
# Instance 350: Processing 120 edges...
# Instance 350: Custom distance 3.02224863 ≈ DP distance 3.02224863.
#
# Instance 351: Processing 120 edges...
# Instance 351: Custom distance 2.70675246 ≈ DP distance 2.70675246.
#
# Instance 352: Processing 120 edges...
# Instance 352: Custom distance 2.94169508 ≈ DP distance 2.94169508.
#
# Instance 353: Processing 120 edges...
# Instance 353: Custom distance 2.65142639 ≈ DP distance 2.65142639.
#
# Instance 354: Processing 120 edges...
# Instance 354: Custom distance 2.75436481 ≈ DP distance 2.75436481.
#
# Instance 355: Processing 120 edges...
# Instance 355: Custom distance 3.10472301 ≈ DP distance 3.10472301.
#
# Instance 356: Processing 120 edges...
# Instance 356: Custom distance 3.27531983 ≈ DP distance 3.27531983.
#
# Instance 357: Processing 120 edges...
# Instance 357: Custom distance 3.01293019 ≈ DP distance 3.01293019.
#
# Instance 358: Processing 120 edges...
# Instance 358: Custom distance 3.08784903 ≈ DP distance 3.08784903.
#
# Instance 359: Processing 120 edges...
# Instance 359: Custom distance 2.75660693 ≈ DP distance 2.75660693.
#
# Instance 360: Processing 120 edges...
# Instance 360: Custom distance 2.52699471 ≈ DP distance 2.52699471.
#
# Instance 361: Processing 120 edges...
# Instance 361: Custom distance 2.66059108 ≈ DP distance 2.66059108.
#
# Instance 362: Processing 120 edges...
# Instance 362: Custom distance 3.29893157 ≈ DP distance 3.29893157.
#
# Instance 363: Processing 120 edges...
# Instance 363: Custom distance 2.92854089 ≈ DP distance 2.92854089.
#
# Instance 364: Processing 120 edges...
# Instance 364: Custom distance 2.81171401 ≈ DP distance 2.81171401.
#
# Instance 365: Processing 120 edges...
# Instance 365: Custom distance 3.24202118 ≈ DP distance 3.24202118.
#
# Instance 366: Processing 120 edges...
# Instance 366: Custom distance 3.10068405 ≈ DP distance 3.10068405.
#
# Instance 367: Processing 120 edges...
# Instance 367: Custom distance 2.72906627 ≈ DP distance 2.72906627.
#
# Instance 368: Processing 120 edges...
# Instance 368: Custom distance 3.14501626 ≈ DP distance 3.14501626.
#
# Instance 369: Processing 120 edges...
# Instance 369: Custom distance 2.70237477 ≈ DP distance 2.70237477.
#
# Instance 370: Processing 120 edges...
# Instance 370: Custom distance 2.99514672 ≈ DP distance 2.99514672.
#
# Instance 371: Processing 120 edges...
# Instance 371: Custom distance 2.81836642 ≈ DP distance 2.81836642.
#
# Instance 372: Processing 120 edges...
# Instance 372: Custom distance 2.65288367 ≈ DP distance 2.65288367.
#
# Instance 373: Processing 120 edges...
# Instance 373: Custom distance 3.06556110 ≈ DP distance 3.06556110.
#
# Instance 374: Processing 120 edges...
# Instance 374: Custom distance 2.52633269 ≈ DP distance 2.52633269.
#
# Instance 375: Processing 120 edges...
# Instance 375: Custom distance 3.11231589 ≈ DP distance 3.11231589.
#
# Instance 376: Processing 120 edges...
# Instance 376: Custom distance 3.36295979 ≈ DP distance 3.36295979.
#
# Instance 377: Processing 120 edges...
# Instance 377: Custom distance 2.90915256 ≈ DP distance 2.90915256.
#
# Instance 378: Processing 120 edges...
# Instance 378: Custom distance 2.68117644 ≈ DP distance 2.68117644.
#
# Instance 379: Processing 120 edges...
# Instance 379: Custom distance 2.82239854 ≈ DP distance 2.82239854.
#
# Instance 380: Processing 120 edges...
# Instance 380: Custom distance 2.85873391 ≈ DP distance 2.85873391.
#
# Instance 381: Processing 120 edges...
# Instance 381: Custom distance 2.87756090 ≈ DP distance 2.87756090.
#
# Instance 382: Processing 120 edges...
# Instance 382: Custom distance 2.53545818 ≈ DP distance 2.53545818.
#
# Instance 383: Processing 120 edges...
# Instance 383: Custom distance 2.95092423 ≈ DP distance 2.95092423.
#
# Instance 384: Processing 120 edges...
# Instance 384: Custom distance 2.87474294 ≈ DP distance 2.87474294.
#
# Instance 385: Processing 120 edges...
# Instance 385: Custom distance 2.62757816 ≈ DP distance 2.62757816.
#
# Instance 386: Processing 120 edges...
# Instance 386: Custom distance 2.78632276 ≈ DP distance 2.78632276.
#
# Instance 387: Processing 120 edges...
# Instance 387: Custom distance 3.41358956 ≈ DP distance 3.41358956.
#
# Instance 388: Processing 120 edges...
# Instance 388: Custom distance 3.26769366 ≈ DP distance 3.26769366.
#
# Instance 389: Processing 120 edges...
# Instance 389: Custom distance 3.08736060 ≈ DP distance 3.08736060.
#
# Instance 390: Processing 120 edges...
# Instance 390: Custom distance 3.09577943 ≈ DP distance 3.09577943.
#
# Instance 391: Processing 120 edges...
# Instance 391: Custom distance 2.42334980 ≈ DP distance 2.42334980.
#
# Instance 392: Processing 120 edges...
# Instance 392: Custom distance 2.99498232 ≈ DP distance 2.99498232.
#
# Instance 393: Processing 120 edges...
# Instance 393: Custom distance 2.63144167 ≈ DP distance 2.63144167.
#
# Instance 394: Processing 120 edges...
# Instance 394: Custom distance 2.76298585 ≈ DP distance 2.76298585.
#
# Instance 395: Processing 120 edges...
# Instance 395: Custom distance 2.75040001 ≈ DP distance 2.75040001.
#
# Instance 396: Processing 120 edges...
# Instance 396: Custom distance 3.40726688 ≈ DP distance 3.40726688.
#
# Instance 397: Processing 120 edges...
# Instance 397: Custom distance 2.37135917 ≈ DP distance 2.37135917.
#
# Instance 398: Processing 120 edges...
# Instance 398: Custom distance 2.98188169 ≈ DP distance 2.98188169.
#
# Instance 399: Processing 120 edges...
# Instance 399: Custom distance 3.01978320 ≈ DP distance 3.01978320.
#
# Instance 400: Processing 120 edges...
# Instance 400: Custom distance 2.54357632 ≈ DP distance 2.54357632.
#
# Instance 401: Processing 120 edges...
# Instance 401: Custom distance 3.05108260 ≈ DP distance 3.05108260.
#
# Instance 402: Processing 120 edges...
# Instance 402: Custom distance 2.98052157 ≈ DP distance 2.98052157.
#
# Instance 403: Processing 120 edges...
# Instance 403: Custom distance 3.41714602 ≈ DP distance 3.41714602.
#
# Instance 404: Processing 120 edges...
# Instance 404: Custom distance 3.07163142 ≈ DP distance 3.07163142.
#
# Instance 405: Processing 120 edges...
# Instance 405: Custom distance 2.72918113 ≈ DP distance 2.72918113.
#
# Instance 406: Processing 120 edges...
# Instance 406: Custom distance 2.78318531 ≈ DP distance 2.78318531.
#
# Instance 407: Processing 120 edges...
# Instance 407: Custom distance 3.65914172 ≈ DP distance 3.65914172.
#
# Instance 408: Processing 120 edges...
# Instance 408: Custom distance 2.76716832 ≈ DP distance 2.76716832.
#
# Instance 409: Processing 120 edges...
# Instance 409: Custom distance 3.34181373 ≈ DP distance 3.34181373.
#
# Instance 410: Processing 120 edges...
# Instance 410: Custom distance 3.14663772 ≈ DP distance 3.14663772.
#
# Instance 411: Processing 120 edges...
# Instance 411: Custom distance 2.83288453 ≈ DP distance 2.83288453.
#
# Instance 412: Processing 120 edges...
# Instance 412: Custom distance 2.89043923 ≈ DP distance 2.89043923.
#
# Instance 413: Processing 120 edges...
# Instance 413: Custom distance 3.55912168 ≈ DP distance 3.55912168.
#
# Instance 414: Processing 120 edges...
# Instance 414: Custom distance 2.37252372 ≈ DP distance 2.37252372.
#
# Instance 415: Processing 120 edges...
# Instance 415: Custom distance 2.83510274 ≈ DP distance 2.83510274.
#
# Instance 416: Processing 120 edges...
# Instance 416: Custom distance 3.00535254 ≈ DP distance 3.00535254.
#
# Instance 417: Processing 120 edges...
# Instance 417: Custom distance 2.89074792 ≈ DP distance 2.89074792.
#
# Instance 418: Processing 120 edges...
# Instance 418: Custom distance 3.18835706 ≈ DP distance 3.18835706.
#
# Instance 419: Processing 120 edges...
# Instance 419: Custom distance 2.92485760 ≈ DP distance 2.92485760.
#
# Instance 420: Processing 120 edges...
# Instance 420: Custom distance 2.40387913 ≈ DP distance 2.40387913.
#
# Instance 421: Processing 120 edges...
# Instance 421: Custom distance 2.98076599 ≈ DP distance 2.98076599.
#
# Instance 422: Processing 120 edges...
# Instance 422: Custom distance 2.78192325 ≈ DP distance 2.78192325.
#
# Instance 423: Processing 120 edges...
# Instance 423: Custom distance 2.98575353 ≈ DP distance 2.98575353.
#
# Instance 424: Processing 120 edges...
# Instance 424: Custom distance 3.00704873 ≈ DP distance 3.00704873.
#
# Instance 425: Processing 120 edges...
# Instance 425: Custom distance 3.10022052 ≈ DP distance 3.10022052.
#
# Instance 426: Processing 120 edges...
# Instance 426: Custom distance 3.31980161 ≈ DP distance 3.31980161.
#
# Instance 427: Processing 120 edges...
# Instance 427: Custom distance 2.65814784 ≈ DP distance 2.65814784.
#
# Instance 428: Processing 120 edges...
# Instance 428: Custom distance 2.94836151 ≈ DP distance 2.94836151.
#
# Instance 429: Processing 120 edges...
# Instance 429: Custom distance 2.60607828 ≈ DP distance 2.60607828.
#
# Instance 430: Processing 120 edges...
# Instance 430: Custom distance 2.52070300 ≈ DP distance 2.52070300.
#
# Instance 431: Processing 120 edges...
# Instance 431: Custom distance 3.12269402 ≈ DP distance 3.12269402.
#
# Instance 432: Processing 120 edges...
# Instance 432: Custom distance 2.44061413 ≈ DP distance 2.44061413.
#
# Instance 433: Processing 120 edges...
# Instance 433: Custom distance 2.74805737 ≈ DP distance 2.74805737.
#
# Instance 434: Processing 120 edges...
# Instance 434: Custom distance 3.31041532 ≈ DP distance 3.31041532.
#
# Instance 435: Processing 120 edges...
# Instance 435: Custom distance 2.14008012 ≈ DP distance 2.14008012.
#
# Instance 436: Processing 120 edges...
# Instance 436: Custom distance 3.05106841 ≈ DP distance 3.05106841.
#
# Instance 437: Processing 120 edges...
# Instance 437: Custom distance 3.15849014 ≈ DP distance 3.15849014.
#
# Instance 438: Processing 120 edges...
# Instance 438: Custom distance 2.94378028 ≈ DP distance 2.94378028.
#
# Instance 439: Processing 120 edges...
# Instance 439: Custom distance 3.53379649 ≈ DP distance 3.53379649.
#
# Instance 440: Processing 120 edges...
# Instance 440: Custom distance 2.94659350 ≈ DP distance 2.94659350.
#
# Instance 441: Processing 120 edges...
# Instance 441: Custom distance 2.79121786 ≈ DP distance 2.79121786.
#
# Instance 442: Processing 120 edges...
# Instance 442: Custom distance 2.50789993 ≈ DP distance 2.50789993.
#
# Instance 443: Processing 120 edges...
# Instance 443: Custom distance 2.56661003 ≈ DP distance 2.56661003.
#
# Instance 444: Processing 120 edges...
# Instance 444: Custom distance 2.18120100 ≈ DP distance 2.18120100.
#
# Instance 445: Processing 120 edges...
# Instance 445: Custom distance 3.18817493 ≈ DP distance 3.18817493.
#
# Instance 446: Processing 120 edges...
# Instance 446: Custom distance 2.87547167 ≈ DP distance 2.87547167.
#
# Instance 447: Processing 120 edges...
# Instance 447: Custom distance 3.07442960 ≈ DP distance 3.07442960.
#
# Instance 448: Processing 120 edges...
# Instance 448: Custom distance 3.01543027 ≈ DP distance 3.01543027.
#
# Instance 449: Processing 120 edges...
# Instance 449: Custom distance 2.81212432 ≈ DP distance 2.81212432.
#
# Instance 450: Processing 120 edges...
# Instance 450: Custom distance 2.60310443 ≈ DP distance 2.60310443.
#
# Instance 451: Processing 120 edges...
# Instance 451: Custom distance 3.04463538 ≈ DP distance 3.04463538.
#
# Instance 452: Processing 120 edges...
# Instance 452: Custom distance 3.06416463 ≈ DP distance 3.06416463.
#
# Instance 453: Processing 120 edges...
# Instance 453: Custom distance 3.19663535 ≈ DP distance 3.19663535.
#
# Instance 454: Processing 120 edges...
# Instance 454: Custom distance 2.06958288 ≈ DP distance 2.06958288.
#
# ...
# Instance 852: Processing 120 edges...
# Instance 852: Custom distance 2.72475548 ≈ DP distance 2.72475548.
#
# Instance 853: Processing 120 edges...
# Instance 853: Custom distance 2.83089488 ≈ DP distance 2.83089488.
#
# Instance 854: Processing 120 edges...
# Instance 854: Custom distance 3.02641260 ≈ DP distance 3.02641260.
#
# Instance 855: Processing 120 edges...
# Instance 855: Custom distance 2.11364900 ≈ DP distance 2.11364900.
#
# Instance 856: Processing 120 edges...
# Instance 856: Custom distance 2.60974028 ≈ DP distance 2.60974028.
#
# Instance 857: Processing 120 edges...
# Instance 857: Custom distance 3.44037630 ≈ DP distance 3.44037630.
#
# Instance 858: Processing 120 edges...
# Instance 858: Custom distance 2.64967700 ≈ DP distance 2.64967700.
#
# Instance 859: Processing 120 edges...
# Instance 859: Custom distance 2.95073176 ≈ DP distance 2.95073176.
#
# Instance 860: Processing 120 edges...
# Instance 860: Custom distance 2.77488184 ≈ DP distance 2.77488184.
#
# Instance 861: Processing 120 edges...
# Instance 861: Custom distance 2.84195137 ≈ DP distance 2.84195137.
#
# Instance 862: Processing 120 edges...
# Instance 862: Custom distance 2.28059678 ≈ DP distance 2.28059678.
#
# Instance 863: Processing 120 edges...
# Instance 863: Custom distance 3.02737809 ≈ DP distance 3.02737809.
#
# Instance 864: Processing 120 edges...
# Instance 864: Custom distance 2.77508762 ≈ DP distance 2.77508762.
#
# Instance 865: Processing 120 edges...
# Instance 865: Custom distance 3.07571035 ≈ DP distance 3.07571035.
#
# Instance 866: Processing 120 edges...
# Instance 866: Custom distance 3.11298915 ≈ DP distance 3.11298915.
#
# Instance 867: Processing 120 edges...
# Instance 867: Custom distance 2.52287679 ≈ DP distance 2.52287679.
#
# Instance 868: Processing 120 edges...
# Instance 868: Custom distance 3.18214489 ≈ DP distance 3.18214489.
#
# Instance 869: Processing 120 edges...
# Instance 869: Custom distance 2.64341022 ≈ DP distance 2.64341022.
#
# Instance 870: Processing 120 edges...
# Instance 870: Custom distance 2.78985369 ≈ DP distance 2.78985369.
#
# Instance 871: Processing 120 edges...
# Instance 871: Custom distance 3.43594631 ≈ DP distance 3.43594631.
#
# Instance 872: Processing 120 edges...
# Instance 872: Custom distance 2.92893902 ≈ DP distance 2.92893902.
#
# Instance 873: Processing 120 edges...
# Instance 873: Custom distance 3.00738594 ≈ DP distance 3.00738594.
#
# Instance 874: Processing 120 edges...
# Instance 874: Custom distance 2.14902141 ≈ DP distance 2.14902141.
#
# Instance 875: Processing 120 edges...
# Instance 875: Custom distance 2.82140722 ≈ DP distance 2.82140722.
#
# Instance 876: Processing 120 edges...
# Instance 876: Custom distance 3.11308419 ≈ DP distance 3.11308419.
#
# Instance 877: Processing 120 edges...
# Instance 877: Custom distance 2.41616595 ≈ DP distance 2.41616595.
#
# Instance 878: Processing 120 edges...
# Instance 878: Custom distance 3.01545383 ≈ DP distance 3.01545383.
#
# Instance 879: Processing 120 edges...
# Instance 879: Custom distance 3.31513508 ≈ DP distance 3.31513508.
#
# Instance 880: Processing 120 edges...
# Instance 880: Custom distance 3.14436283 ≈ DP distance 3.14436283.
#
# Instance 881: Processing 120 edges...
# Instance 881: Custom distance 3.17399077 ≈ DP distance 3.17399077.
#
# Instance 882: Processing 120 edges...
# Instance 882: Custom distance 3.62986752 ≈ DP distance 3.62986752.
#
# Instance 883: Processing 120 edges...
# Instance 883: Custom distance 3.23594372 ≈ DP distance 3.23594372.
#
# Instance 884: Processing 120 edges...
# Instance 884: Custom distance 3.09050962 ≈ DP distance 3.09050962.
#
# Instance 885: Processing 120 edges...
# Instance 885: Custom distance 3.28662097 ≈ DP distance 3.28662097.
#
# Instance 886: Processing 120 edges...
# Instance 886: Custom distance 3.01383364 ≈ DP distance 3.01383364.
#
# Instance 887: Processing 120 edges...
# Instance 887: Custom distance 3.36636236 ≈ DP distance 3.36636236.
#
# Instance 888: Processing 120 edges...
# Instance 888: Custom distance 3.07314235 ≈ DP distance 3.07314235.
#
# Instance 889: Processing 120 edges...
# Instance 889: Custom distance 2.98282650 ≈ DP distance 2.98282650.
#
# Instance 890: Processing 120 edges...
# Instance 890: Custom distance 3.01005178 ≈ DP distance 3.01005178.
#
# Instance 891: Processing 120 edges...
# Instance 891: Custom distance 2.57536236 ≈ DP distance 2.57536236.
#
# Instance 892: Processing 120 edges...
# Instance 892: Custom distance 2.69320026 ≈ DP distance 2.69320026.
#
# Instance 893: Processing 120 edges...
# Instance 893: Custom distance 2.89936270 ≈ DP distance 2.89936270.
#
# Instance 894: Processing 120 edges...
# Instance 894: Custom distance 2.64166166 ≈ DP distance 2.64166166.
#
# Instance 895: Processing 120 edges...
# Instance 895: Custom distance 2.78146784 ≈ DP distance 2.78146784.
#
# Instance 896: Processing 120 edges...
# Instance 896: Custom distance 3.03839921 ≈ DP distance 3.03839921.
#
# Instance 897: Processing 120 edges...
# Instance 897: Custom distance 2.57829830 ≈ DP distance 2.57829830.
#
# Instance 898: Processing 120 edges...
# Instance 898: Custom distance 2.62445338 ≈ DP distance 2.62445338.
#
# Instance 899: Processing 120 edges...
# Instance 899: Custom distance 3.28287174 ≈ DP distance 3.28287174.
#
# Instance 900: Processing 120 edges...
# Instance 900: Custom distance 2.79458449 ≈ DP distance 2.79458449.
#
# Instance 901: Processing 120 edges...
# Instance 901: Custom distance 2.77482575 ≈ DP distance 2.77482575.
#
# Instance 902: Processing 120 edges...
# Instance 902: Custom distance 2.86952520 ≈ DP distance 2.86952520.
#
# Instance 903: Processing 120 edges...
# Instance 903: Custom distance 3.07892121 ≈ DP distance 3.07892121.
#
# Instance 904: Processing 120 edges...
# Instance 904: Custom distance 2.85876703 ≈ DP distance 2.85876703.
#
# Instance 905: Processing 120 edges...
# Instance 905: Custom distance 3.35205857 ≈ DP distance 3.35205857.
#
# Instance 906: Processing 120 edges...
# Instance 906: Custom distance 2.70826946 ≈ DP distance 2.70826946.
#
# Instance 907: Processing 120 edges...
# Instance 907: Custom distance 3.25699149 ≈ DP distance 3.25699149.
#
# Instance 908: Processing 120 edges...
# Instance 908: Custom distance 2.98592393 ≈ DP distance 2.98592393.
#
# Instance 909: Processing 120 edges...
# Instance 909: Custom distance 2.50878591 ≈ DP distance 2.50878591.
#
# Instance 910: Processing 120 edges...
# Instance 910: Custom distance 2.74366951 ≈ DP distance 2.74366951.
#
# Instance 911: Processing 120 edges...
# Instance 911: Custom distance 3.25780351 ≈ DP distance 3.25780351.
#
# Instance 912: Processing 120 edges...
# Instance 912: Custom distance 3.24400759 ≈ DP distance 3.24400759.
#
# Instance 913: Processing 120 edges...
# Instance 913: Custom distance 3.08018154 ≈ DP distance 3.08018154.
#
# Instance 914: Processing 120 edges...
# Instance 914: Custom distance 2.42006003 ≈ DP distance 2.42006003.
#
# Instance 915: Processing 120 edges...
# Instance 915: Custom distance 3.34050906 ≈ DP distance 3.34050906.
#
# Instance 916: Processing 120 edges...
# Instance 916: Custom distance 2.68627123 ≈ DP distance 2.68627123.
#
# Instance 917: Processing 120 edges...
# Instance 917: Custom distance 2.78024648 ≈ DP distance 2.78024648.
#
# Instance 918: Processing 120 edges...
# Instance 918: Custom distance 2.46284240 ≈ DP distance 2.46284240.
#
# Instance 919: Processing 120 edges...
# Instance 919: Custom distance 3.35514209 ≈ DP distance 3.35514209.
#
# Instance 920: Processing 120 edges...
# Instance 920: Custom distance 3.07339320 ≈ DP distance 3.07339320.
#
# Instance 921: Processing 120 edges...
# Instance 921: Custom distance 2.96018874 ≈ DP distance 2.96018874.
#
# Instance 922: Processing 120 edges...
# Instance 922: Custom distance 2.83253309 ≈ DP distance 2.83253309.
#
# Instance 923: Processing 120 edges...
# Instance 923: Custom distance 2.73465640 ≈ DP distance 2.73465640.
#
# Instance 924: Processing 120 edges...
# Instance 924: Custom distance 3.30409166 ≈ DP distance 3.30409166.
#
# Instance 925: Processing 120 edges...
# Instance 925: Custom distance 3.39454838 ≈ DP distance 3.39454838.
#
# Instance 926: Processing 120 edges...
# Instance 926: Custom distance 3.30586511 ≈ DP distance 3.30586511.
#
# Instance 927: Processing 120 edges...
# Instance 927: Custom distance 2.75738441 ≈ DP distance 2.75738441.
#
# Instance 928: Processing 120 edges...
# Instance 928: Custom distance 2.92316647 ≈ DP distance 2.92316647.
#
# Instance 929: Processing 120 edges...
# Instance 929: Custom distance 2.80980839 ≈ DP distance 2.80980839.
#
# Instance 930: Processing 120 edges...
# Instance 930: Custom distance 3.15916658 ≈ DP distance 3.15916658.
#
# Instance 931: Processing 120 edges...
# Instance 931: Custom distance 2.59112833 ≈ DP distance 2.59112833.
#
# Instance 932: Processing 120 edges...
# Instance 932: Custom distance 2.81073834 ≈ DP distance 2.81073834.
#
# Instance 933: Processing 120 edges...
# Instance 933: Custom distance 2.59940007 ≈ DP distance 2.59940007.
#
# Instance 934: Processing 120 edges...
# Instance 934: Custom distance 3.10506047 ≈ DP distance 3.10506047.
#
# Instance 935: Processing 120 edges...
# Instance 935: Custom distance 2.92178014 ≈ DP distance 2.92178014.
#
# Instance 936: Processing 120 edges...
# Instance 936: Custom distance 2.77232509 ≈ DP distance 2.77232509.
#
# Instance 937: Processing 120 edges...
# Instance 937: Custom distance 2.57420832 ≈ DP distance 2.57420832.
#
# Instance 938: Processing 120 edges...
# Instance 938: Custom distance 2.65553243 ≈ DP distance 2.65553243.
#
# Instance 939: Processing 120 edges...
# Instance 939: Custom distance 2.43379708 ≈ DP distance 2.43379708.
#
# Instance 940: Processing 120 edges...
# Instance 940: Custom distance 3.41780229 ≈ DP distance 3.41780229.
#
# Instance 941: Processing 120 edges...
# Instance 941: Custom distance 2.97143721 ≈ DP distance 2.97143721.
#
# Instance 942: Processing 120 edges...
# Instance 942: Custom distance 2.78463141 ≈ DP distance 2.78463141.
#
# Instance 943: Processing 120 edges...
# Instance 943: Custom distance 3.01744617 ≈ DP distance 3.01744617.
#
# Instance 944: Processing 120 edges...
# Instance 944: Custom distance 2.73711485 ≈ DP distance 2.73711485.
#
# Instance 945: Processing 120 edges...
# Instance 945: Custom distance 2.91374613 ≈ DP distance 2.91374613.
#
# Instance 946: Processing 120 edges...
# Instance 946: Custom distance 2.89430634 ≈ DP distance 2.89430634.
#
# Instance 947: Processing 120 edges...
# Instance 947: Custom distance 3.24161456 ≈ DP distance 3.24161456.
#
# Instance 948: Processing 120 edges...
# Instance 948: Custom distance 2.30261280 ≈ DP distance 2.30261280.
#
# Instance 949: Processing 120 edges...
# Instance 949: Custom distance 2.86417047 ≈ DP distance 2.86417047.
#
# Instance 950: Processing 120 edges...
# Instance 950: Custom distance 3.47683626 ≈ DP distance 3.47683626.
#
# Instance 951: Processing 120 edges...
# Instance 951: Custom distance 2.97106878 ≈ DP distance 2.97106878.
#
# Instance 952: Processing 120 edges...
# Instance 952: Custom distance 2.81905518 ≈ DP distance 2.81905518.
#
# Instance 953: Processing 120 edges...
# Instance 953: Custom distance 2.64207436 ≈ DP distance 2.64207436.
#
# Instance 954: Processing 120 edges...
# Instance 954: Custom distance 3.08808457 ≈ DP distance 3.08808457.
#
# Instance 955: Processing 120 edges...
# Instance 955: Custom distance 3.15614416 ≈ DP distance 3.15614416.
#
# Instance 956: Processing 120 edges...
# Instance 956: Custom distance 2.93354751 ≈ DP distance 2.93354751.
#
# Instance 957: Processing 120 edges...
# Instance 957: Custom distance 2.76169144 ≈ DP distance 2.76169144.
#
# Instance 958: Processing 120 edges...
# Instance 958: Custom distance 2.98836565 ≈ DP distance 2.98836565.
#
# Instance 959: Processing 120 edges...
# Instance 959: Custom distance 2.96853633 ≈ DP distance 2.96853633.
#
# Instance 960: Processing 120 edges...
# Instance 960: Custom distance 2.86425209 ≈ DP distance 2.86425209.
#
# Instance 961: Processing 120 edges...
# Instance 961: Custom distance 3.12157772 ≈ DP distance 3.12157772.
#
# Instance 962: Processing 120 edges...
# Instance 962: Custom distance 2.59443150 ≈ DP distance 2.59443150.
#
# Instance 963: Processing 120 edges...
# Instance 963: Custom distance 2.65319149 ≈ DP distance 2.65319149.
#
# Instance 964: Processing 120 edges...
# Instance 964: Custom distance 2.94692651 ≈ DP distance 2.94692651.
#
# Instance 965: Processing 120 edges...
# Instance 965: Custom distance 3.01251309 ≈ DP distance 3.01251309.
#
# Instance 966: Processing 120 edges...
# Instance 966: Custom distance 3.05923925 ≈ DP distance 3.05923925.
#
# Instance 967: Processing 120 edges...
# Instance 967: Custom distance 2.84546196 ≈ DP distance 2.84546196.
#
# Instance 968: Processing 120 edges...
# Instance 968: Custom distance 2.97189661 ≈ DP distance 2.97189661.
#
# Instance 969: Processing 120 edges...
# Instance 969: Custom distance 2.45030836 ≈ DP distance 2.45030836.
#
# Instance 970: Processing 120 edges...
# Instance 970: Custom distance 2.96645385 ≈ DP distance 2.96645385.
#
# Instance 971: Processing 120 edges...
# Instance 971: Custom distance 2.96188475 ≈ DP distance 2.96188475.
#
# Instance 972: Processing 120 edges...
# Instance 972: Custom distance 3.06490167 ≈ DP distance 3.06490167.
#
# Instance 973: Processing 120 edges...
# Instance 973: Custom distance 2.56268191 ≈ DP distance 2.56268191.
#
# Instance 974: Processing 120 edges...
# Instance 974: Custom distance 2.30276017 ≈ DP distance 2.30276017.
#
# Instance 975: Processing 120 edges...
# Instance 975: Custom distance 2.62260328 ≈ DP distance 2.62260328.
#
# Instance 976: Processing 120 edges...
# Instance 976: Custom distance 2.87791006 ≈ DP distance 2.87791006.
#
# Instance 977: Processing 120 edges...
# Instance 977: Custom distance 2.58656430 ≈ DP distance 2.58656430.
#
# Instance 978: Processing 120 edges...
# Instance 978: Custom distance 3.15399508 ≈ DP distance 3.15399508.
#
# Instance 979: Processing 120 edges...
# Instance 979: Custom distance 2.57609459 ≈ DP distance 2.57609459.
#
# Instance 980: Processing 120 edges...
# Instance 980: Custom distance 2.91673041 ≈ DP distance 2.91673041.
#
# Instance 981: Processing 120 edges...
# Instance 981: Custom distance 3.04167015 ≈ DP distance 3.04167015.
#
# Instance 982: Processing 120 edges...
# Instance 982: Custom distance 2.94151101 ≈ DP distance 2.94151101.
#
# Instance 983: Processing 120 edges...
# Instance 983: Custom distance 2.56775918 ≈ DP distance 2.56775918.
#
# Instance 984: Processing 120 edges...
# Instance 984: Custom distance 3.05281343 ≈ DP distance 3.05281343.
#
# Instance 985: Processing 120 edges...
# Instance 985: Custom distance 2.87443475 ≈ DP distance 2.87443475.
#
# Instance 986: Processing 120 edges...
# Instance 986: Custom distance 2.78157206 ≈ DP distance 2.78157206.
#
# Instance 987: Processing 120 edges...
# Instance 987: Custom distance 2.84661941 ≈ DP distance 2.84661941.
#
# Instance 988: Processing 120 edges...
# Instance 988: Custom distance 3.07816045 ≈ DP distance 3.07816045.
#
# Instance 989: Processing 120 edges...
# Instance 989: Custom distance 2.91009739 ≈ DP distance 2.91009739.
#
# Instance 990: Processing 120 edges...
# Instance 990: Custom distance 2.78468196 ≈ DP distance 2.78468196.
#
# Instance 991: Processing 120 edges...
# Instance 991: Custom distance 3.00739817 ≈ DP distance 3.00739817.
#
# Instance 992: Processing 120 edges...
# Instance 992: Custom distance 2.69931175 ≈ DP distance 2.69931175.
#
# Instance 993: Processing 120 edges...
# Instance 993: Custom distance 2.68909283 ≈ DP distance 2.68909283.
#
# Instance 994: Processing 120 edges...
# Instance 994: Custom distance 2.32952283 ≈ DP distance 2.32952283.
#
# Instance 995: Processing 120 edges...
# Instance 995: Custom distance 2.62899145 ≈ DP distance 2.62899145.
#
# Instance 996: Processing 120 edges...
# Instance 996: Custom distance 3.47752713 ≈ DP distance 3.47752713.
#
# Instance 997: Processing 120 edges...
# Instance 997: Custom distance 3.21583626 ≈ DP distance 3.21583626.
#
# Instance 998: Processing 120 edges...
# Instance 998: Custom distance 2.83299065 ≈ DP distance 2.83299065.
#
# Instance 999: Processing 120 edges...
# Instance 999: Custom distance 3.00790507 ≈ DP distance 3.00790507.
#
# Instance 1000: Processing 120 edges...
# Instance 1000: Custom distance 2.72648768 ≈ DP distance 2.72648768.
#
# Benchmarking Summary:
# Total Instances Run: 1000 out of 1000
# Custom Algorithm - Average Distance: 2.90293837
# DP Solution       - Average Distance: 2.90293837
# Average Improvement by Custom Algorithm: 0.00%
